# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/Koalas_Install_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install koalas

# %%
# !pip install pyarrow==0.15.1

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.0-preview2/spark-3.0.0-preview2-bin-hadoop2.7.tgz
# !tar xf spark-3.0.0-preview2-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
# !ls /usr/lib/jvm/
# Out:
# default-java		   java-11-openjdk-amd64     java-8-openjdk-amd64
# java-1.11.0-openjdk-amd64  java-1.8.0-openjdk-amd64

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-preview2-bin-hadoop2.7"

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
import sys,tempfile, urllib
from pyspark.sql.functions import *

# %%
BASE_DIR = '/tmp'
CORONA_DATA_FILE = os.path.join(BASE_DIR, 'corona_data.csv')

# %%
corona_data=urllib.request.urlretrieve('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/coronavirus/corona_dataset_latest.csv', CORONA_DATA_FILE)

# %%
# !ls /tmp
# Out:
# blockmgr-af2763d2-a6e4-4da9-a109-05233d01ea33
# corona_data.csv
# hsperfdata_root
# spark-59e8159a-4bd1-4c40-9603-377c2ce27f58
# spark-62e26538-b2d4-4e1f-8154-3cb9e48d949f

# %%
import databricks.koalas as ks

# %%
df=ks.read_csv("/tmp/corona_data.csv")

# %%
df.count()
# Out:
# _c0              28143
# State            19116
# Country          28143
# Lat              28143
# Long             28143
# Date             28143
# Confirmed        28143
# Death            28143
# Recovered        28143
# state_cleaned    28143
# City             14573
# Name: 0, dtype: int64
