# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/TPOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link to supporting video for below notebook walkhthrough - https://www.youtube.com/watch?v=oIFSpnFGX8s

# %%
# !pip install tpot

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/EpistasisLab/tpot/master/images/tpot-ml-pipeline.png)

# %% [markdown]
# **Import TPOT packages and load Telecom Churn dataset**

# %%
from tpot import  TPOTClassifier
from sklearn.model_selection import train_test_split
from __future__ import print_function
import sys,tempfile, urllib, os
import pandas as pd
import numpy as np

# %%
BASE_DIR = '/tmp'
OUTPUT_FILE = os.path.join(BASE_DIR, 'churn_data.csv')

churn_data=urllib.request.urlretrieve('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv', OUTPUT_FILE)

# %%
churn_df = pd.read_csv(OUTPUT_FILE)

# %%
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
print ("Rows     : " ,churn_df.shape[0])
print ("Columns  : " ,churn_df.shape[1])
# Out:
# Rows     :  7043
# Columns  :  21

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder

categorical_columns = ['gender', 'Partner', 'Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','Churn']
column_trans = make_column_transformer((OrdinalEncoder(), categorical_columns))

churn_transformed=column_trans.fit_transform(churn_df)

# %%
churn_df_trans = churn_df.copy()
churn_df_trans = pd.DataFrame(churn_transformed, columns=categorical_columns)

# %%
churn_df.update(churn_df_trans)

# %%
churn_df
# Out:
#       customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG      0              0  ...          29.85        29.85      0
# 1     5575-GNVDE      1              0  ...          56.95       1889.5      0
# 2     3668-QPYBK      1              0  ...          53.85       108.15      1
# 3     7795-CFOCW      1              0  ...          42.30      1840.75      0
# 4     9237-HQITU      0              0  ...          70.70       151.65      1
# ...          ...    ...            ...  ...            ...          ...    ...
# 7038  6840-RESVB      1              0  ...          84.80       1990.5      0
# 7039  2234-XADUH      0              0  ...         103.20       7362.9      0
# 7040  4801-JZAZL      0              0  ...          29.60       346.45      0
# 7041  8361-LTMKD      1              1  ...          74.40        306.6      1
# 7042  3186-AJIEK      1              0  ...         105.65       6844.5      0
#
# [7043 rows x 21 columns]

# %%
churn_df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_df.replace(r'^\s*$', np.nan, regex=True).isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
churn_df = churn_df.replace(r'^\s*$', np.nan, regex=True)

# %%
churn_df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
churn_df.dtypes
# Out:
# customerID           object
# gender              float64
# SeniorCitizen         int64
# Partner             float64
# Dependents          float64
# tenure                int64
# PhoneService        float64
# MultipleLines       float64
# InternetService     float64
# OnlineSecurity      float64
# OnlineBackup        float64
# DeviceProtection    float64
# TechSupport         float64
# StreamingTV         float64
# StreamingMovies     float64
# Contract            float64
# PaperlessBilling    float64
# PaymentMethod       float64
# MonthlyCharges      float64
# TotalCharges         object
# Churn               float64
# dtype: object

# %%
churn_df.iloc[:, 19] = pd.to_numeric(churn_df.iloc[:, 19], errors='coerce')

# %%
from sklearn.impute import SimpleImputer
imp_median = SimpleImputer(missing_values=np.nan, strategy='median')

# %%
churn_df.iloc[:, 19] = imp_median.fit_transform(churn_df.iloc[:, 19].values.reshape(-1, 1) )

# %%
churn_df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_df_X = churn_df.drop("Churn", axis=1)
churn_df_X = churn_df_X.drop("customerID", axis=1)
churn_df_y = churn_df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(churn_df_X, churn_df_y, train_size=0.75, test_size=0.25)

# %%
X_train
# Out:
#       gender  SeniorCitizen  ...  MonthlyCharges  TotalCharges
# 3507     1.0              0  ...           19.75         78.30
# 5729     0.0              0  ...           51.05       1815.00
# 5203     1.0              0  ...           70.70        225.65
# 4073     1.0              0  ...           65.45        937.60
# 1786     0.0              0  ...           84.25       3264.50
# ...      ...            ...  ...             ...           ...
# 4100     1.0              0  ...           19.80       1013.20
# 5211     0.0              0  ...           84.90        764.95
# 3574     0.0              0  ...           20.35         20.35
# 2753     0.0              0  ...           95.65         95.65
# 1015     1.0              0  ...           53.65        696.35
#
# [5282 rows x 19 columns]

# %% [markdown]
# **Use TPOT classifier to find the best model algorithm that fits the data. TPOT uses genetic algorithm based search internally**

# %%
tpot =  TPOTClassifier(generations=4, population_size=10, verbosity=3)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
# Out:
# 31 operators have been imported by TPOT.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=50.0, style=ProgressStyle(des…
# Generation 1 - Current Pareto front scores:
# -1	0.7993115225983846	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=17, RandomForestClassifier__min_samples_split=11, RandomForestClassifier__n_estimators=100)
#
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18']
# expected gender, tenure, OnlineSecurity, TotalCharges, StreamingMovies, Partner, MonthlyCharges, TechSupport, StreamingTV, OnlineBackup, MultipleLines, DeviceProtection, Contract, InternetService, PaperlessBilling, Dependents, PhoneService, PaymentMethod, SeniorCitizen in input data
# training data did not have the following fields: f10, f12, f17, f0, f4, f6, f11, f3, f7, f9, f2, f1, f8, f14, f16, f5, f13, f15, f18.
# Generation 2 - Current Pareto front scores:
# -1	0.7993115225983846	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=17, RandomForestClassifier__min_samples_split=11, RandomForestClassifier__n_estimators=100)
#
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 98.
# Generation 3 - Current Pareto front scores:
# -1	0.8002574182276451	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.35000000000000003, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=20, RandomForestClassifier__n_estimators=100)
#
# Generation 4 - Current Pareto front scores:
# -1	0.8002574182276451	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.35000000000000003, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=20, RandomForestClassifier__n_estimators=100)
#
# 0.8069278818852924

# %%
import multiprocessing

if __name__ == '__main__':
    multiprocessing.set_start_method('forkserver', force=True)
    tpot =  TPOTClassifier(generations=2, population_size=20, verbosity=2,n_jobs = 20, random_state=50)
    tpot.fit(X_train, y_train)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=60.0, style=ProgressStyle(des…
# Generation 1 - Current best internal CV score: 0.8099193731265857
# Generation 2 - Current best internal CV score: 0.8099193731265857
#
# Best pipeline: XGBClassifier(input_matrix, learning_rate=0.1, max_depth=8, min_child_weight=18, n_estimators=100, nthread=1, subsample=0.3)

# %%
print(tpot.score(X_test, y_test))
# Out:
# 0.7842135150482681

# %% [markdown]
# **Export the scikit learn code for best classifier and dispay the code**

# %%
tpot.export('tpot_churn_pipeline.py')

# %%
# !cat tpot_churn_pipeline.py
# Out:
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from xgboost import XGBClassifier
# from tpot.export_utils import set_param_recursive
#
# # NOTE: Make sure that the outcome column is labeled 'target' in the data file
# tpot_data = pd.read_csv('PATH/TO/DATA/FILE', sep='COLUMN_SEPARATOR', dtype=np.float64)
# features = tpot_data.drop('target', axis=1)
# training_features, testing_features, training_target, testing_target = \
#             train_test_split(features, tpot_data['target'], random_state=50)
#
# # Average CV score on the training set was: 0.8099193731265857
# exported_pipeline = XGBClassifier(learning_rate=0.1, max_depth=8, min_child_weight=18, n_estimators=100, nthread=1, subsample=0.3)
# # Fix random state for all the steps in exported pipeline
# set_param_recursive(exported_pipeline.steps, 'random_state', 50)
#
# exported_pipeline.fit(training_features, training_target)
# results = exported_pipeline.predict(testing_features)

# %% [markdown]
# **Get details on algorithm TPOT searched for and how the performed on the dataset**

# %%
tpot.evaluated_individuals_
# Out:
# {'BernoulliNB(BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7485820572954138,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'BernoulliNB(LinearSVC(SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=1.0, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0), LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7695935016225104,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('BernoulliNB(LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7669419844329216,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'BernoulliNB(MinMaxScaler(LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1)), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7669419844329216,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('BernoulliNB(LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7247279079948331,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(BernoulliNB(input_matrix, BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7529372247156922,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('BernoulliNB(LinearSVC(input_matrix, LinearSVC__C=0.5, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.1), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)',)},
#  'ExtraTreesClassifier(MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=False), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.804998355614234,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)',)},
#  'ExtraTreesClassifier(PCA(SelectPercentile(input_matrix, SelectPercentile__percentile=13), PCA__iterated_power=10, PCA__svd_solver=randomized), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7854995542732903,
#   'mutation_count': 2,
#   'operator_count': 3,
#   'predecessor': ('ExtraTreesClassifier(SelectPercentile(input_matrix, SelectPercentile__percentile=13), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)',)},
#  'ExtraTreesClassifier(SelectPercentile(input_matrix, SelectPercentile__percentile=13), ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7836057923615988,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)',)},
#  'ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7960979104513911,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'GaussianNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False))': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.4905360359616739,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',)},
#  'GaussianNB(input_matrix)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.756532125271964,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',)},
#  'GradientBoostingClassifier(GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.001, GradientBoostingClassifier__max_depth=5, GradientBoostingClassifier__max_features=0.8, GradientBoostingClassifier__min_samples_leaf=15, GradientBoostingClassifier__min_samples_split=10, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=1.0), GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7283120420873082,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)',)},
#  'GradientBoostingClassifier(RBFSampler(input_matrix, RBFSampler__gamma=0.4), GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6595949950209861,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)',)},
#  'GradientBoostingClassifier(SelectPercentile(input_matrix, SelectPercentile__percentile=70), GradientBoostingClassifier__learning_rate=0.1, GradientBoostingClassifier__max_depth=1, GradientBoostingClassifier__max_features=0.7500000000000001, GradientBoostingClassifier__min_samples_leaf=20, GradientBoostingClassifier__min_samples_split=19, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.6000000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.8080275842400383,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.1, GradientBoostingClassifier__max_depth=1, GradientBoostingClassifier__max_features=0.7500000000000001, GradientBoostingClassifier__min_samples_leaf=20, GradientBoostingClassifier__min_samples_split=19, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.6000000000000001)',)},
#  'GradientBoostingClassifier(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.005), GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=13, GradientBoostingClassifier__min_samples_split=13, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.3)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7504759960099954,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=13, GradientBoostingClassifier__min_samples_split=13, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.3)',)},
#  'GradientBoostingClassifier(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.05), GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7501067104798156,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)',)},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.1, GradientBoostingClassifier__max_depth=1, GradientBoostingClassifier__max_features=0.7500000000000001, GradientBoostingClassifier__min_samples_leaf=20, GradientBoostingClassifier__min_samples_split=19, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.6000000000000001)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.8072680351176397,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.1, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.7500000000000001, GradientBoostingClassifier__min_samples_leaf=12, GradientBoostingClassifier__min_samples_split=9, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.5)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.791556038839434,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.35000000000000003, GradientBoostingClassifier__min_samples_leaf=13, GradientBoostingClassifier__min_samples_split=13, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.3)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7345688662372855,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=13, GradientBoostingClassifier__min_samples_split=13, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.3)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7504759960099954,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.35000000000000003, GradientBoostingClassifier__min_samples_leaf=13, GradientBoostingClassifier__min_samples_split=13, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.3)',
#    'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)')},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=13, GradientBoostingClassifier__min_samples_split=6, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.3)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7504759960099954,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=13, GradientBoostingClassifier__min_samples_split=13, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.3)',)},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=9, GradientBoostingClassifier__max_features=0.6500000000000001, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=4, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.55)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7501067104798156,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'KNeighborsClassifier(GaussianNB(input_matrix), KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7854970423475022,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',)},
#  'KNeighborsClassifier(MinMaxScaler(GaussianNB(input_matrix)), KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7817102396625166,
#   'mutation_count': 2,
#   'operator_count': 3,
#   'predecessor': ('KNeighborsClassifier(MinMaxScaler(input_matrix), KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',
#    'KNeighborsClassifier(GaussianNB(input_matrix), KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)')},
#  'KNeighborsClassifier(MinMaxScaler(input_matrix), KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7784950222088888,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',)},
#  'KNeighborsClassifier(Nystroem(input_matrix, Nystroem__gamma=0.7000000000000001, Nystroem__kernel=linear, Nystroem__n_components=2), KNeighborsClassifier__n_neighbors=71, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7832210843883421,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'KNeighborsClassifier(ZeroCount(MinMaxScaler(input_matrix)), KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7711082920589448,
#   'mutation_count': 2,
#   'operator_count': 3,
#   'predecessor': ('KNeighborsClassifier(MinMaxScaler(input_matrix), KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',)},
#  'KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7853074688877866,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'LinearSVC(DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=1, DecisionTreeClassifier__min_samples_split=7), LinearSVC__C=0.01, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7152117386996627,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LinearSVC(input_matrix, LinearSVC__C=0.01, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)',)},
#  'LinearSVC(input_matrix, LinearSVC__C=0.01, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.001)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7319609194959545,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'LogisticRegression(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=euclidean, FeatureAgglomeration__linkage=average), LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7688337746781848,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'LogisticRegression(ZeroCount(RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=2, RandomForestClassifier__min_samples_split=13, RandomForestClassifier__n_estimators=100)), LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7919323188685811,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('LogisticRegression(ZeroCount(input_matrix), LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(ZeroCount(input_matrix), LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.8091625137519021,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7894710938993525,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(FeatureAgglomeration(input_matrix, FeatureAgglomeration__affinity=euclidean, FeatureAgglomeration__linkage=average), LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=10.0, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7485266374868867,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=True, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.8070802544833885,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(ZeroCount(input_matrix), LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7525062453370573,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.1, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=8, ExtraTreesClassifier__n_estimators=100)',)},
#  'MultinomialNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.5816006872588194,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',
#    'MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)')},
#  'MultinomialNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.5816006872588194,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'MultinomialNB(SGDClassifier(input_matrix, SGDClassifier__alpha=0.001, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=1.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6571387945826915,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('MultinomialNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), MultinomialNB__alpha=0.1, MultinomialNB__fit_prior=False)',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.6616815624375415,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.6554344276294308,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=5, RandomForestClassifier__min_samples_split=13, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.8042395245731221,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=29, KNeighborsClassifier__p=2, KNeighborsClassifier__weights=uniform)',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.6000000000000001, RandomForestClassifier__min_samples_leaf=4, RandomForestClassifier__min_samples_split=17, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.8032925538571154,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.01, MultinomialNB__fit_prior=False)',)},
#  'SGDClassifier(MaxAbsScaler(input_matrix), SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7262656556326716,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',)},
#  'SGDClassifier(Normalizer(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=entropy, RFE__ExtraTreesClassifier__max_features=0.6500000000000001, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.55), Normalizer__norm=l1), SGDClassifier__alpha=0.001, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7540732279526965,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('SGDClassifier(Normalizer(input_matrix, Normalizer__norm=l1), SGDClassifier__alpha=0.001, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1)',)},
#  'SGDClassifier(Normalizer(input_matrix, Normalizer__norm=l1), SGDClassifier__alpha=0.001, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=constant, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.1)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7474512492780124,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'SGDClassifier(Normalizer(input_matrix, Normalizer__norm=l2), SGDClassifier__alpha=0.001, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7728140961938159,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'SGDClassifier(Normalizer(input_matrix, Normalizer__norm=l2), SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7623974227335704,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('SGDClassifier(Normalizer(input_matrix, Normalizer__norm=l2), SGDClassifier__alpha=0.001, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)',)},
#  'SGDClassifier(SGDClassifier(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6520836043971303,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('SGDClassifier(SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0)',)},
#  'SGDClassifier(SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.0, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0), SGDClassifier__alpha=0.0, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=constant, SGDClassifier__loss=modified_huber, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=50.0)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7618331859466396,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7639145482929027,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)',)},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.730425867380373,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',
#    'SGDClassifier(Normalizer(input_matrix, Normalizer__norm=l2), SGDClassifier__alpha=0.001, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.75, SGDClassifier__learning_rate=constant, SGDClassifier__loss=squared_hinge, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=10.0)')},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=0.01, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=100.0)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.35615136453787155,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.741954696068189,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',
#    'SGDClassifier(input_matrix, SGDClassifier__alpha=0.0, SGDClassifier__eta0=0.1, SGDClassifier__fit_intercept=False, SGDClassifier__l1_ratio=0.5, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=perceptron, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)')},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=constant, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7400607566742495,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)',)},
#  'SGDClassifier(input_matrix, SGDClassifier__alpha=0.01, SGDClassifier__eta0=1.0, SGDClassifier__fit_intercept=True, SGDClassifier__l1_ratio=0.25, SGDClassifier__learning_rate=invscaling, SGDClassifier__loss=log, SGDClassifier__penalty=elasticnet, SGDClassifier__power_t=0.0)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7400607566742495,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=18, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.3)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.8099193731265857,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('MultinomialNB(input_matrix, MultinomialNB__alpha=0.001, MultinomialNB__fit_prior=True)',)}}

# %%
tpot.fitted_pipeline_
# Out:
# Pipeline(memory=None,
#          steps=[('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=8,
#                                min_child_weight=18, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=1,
#                                objective='binary:logistic', random_state=50,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=0.3,
#                                verbosity=1))],
#          verbose=False)
