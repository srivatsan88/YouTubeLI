# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/TPOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tpot

# %% [markdown]
# **Import TPOT packages and load wine dataset**

# %%
from tpot import  TPOTClassifier
from sklearn.model_selection import train_test_split
from __future__ import print_function
import sys,tempfile, urllib, os
import pandas as pd
import numpy as np

# %%
BASE_DIR = '/tmp'
OUTPUT_FILE = os.path.join(BASE_DIR, 'churn_data.csv')

churn_data=urllib.request.urlretrieve('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv', OUTPUT_FILE)

# %%
churn_df = pd.read_csv(OUTPUT_FILE)

# %%
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder

categorical_columns = ['gender', 'Partner', 'Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','Churn']
column_trans = make_column_transformer((categorical_columns, OrdinalEncoder()))

out=column_trans.fit_transform(churn_df)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/compose/_column_transformer.py:778: DeprecationWarning: `make_column_transformer` now expects (transformer, columns) as input tuples instead of (columns, transformer). This has been introduced in v0.20.1. `make_column_transformer` will stop accepting the deprecated (columns, transformer) order in v0.22.
#   warnings.warn(message, DeprecationWarning)

# %%
churn_df_trans = churn_df.copy()
churn_df_trans = pd.DataFrame(out, columns=categorical_columns)

# %%
churn_df.update(churn_df_trans)

# %%
churn_df
# Out:
#       customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG      0              0  ...          29.85        29.85      0
# 1     5575-GNVDE      1              0  ...          56.95       1889.5      0
# 2     3668-QPYBK      1              0  ...          53.85       108.15      1
# 3     7795-CFOCW      1              0  ...          42.30      1840.75      0
# 4     9237-HQITU      0              0  ...          70.70       151.65      1
# ...          ...    ...            ...  ...            ...          ...    ...
# 7038  6840-RESVB      1              0  ...          84.80       1990.5      0
# 7039  2234-XADUH      0              0  ...         103.20       7362.9      0
# 7040  4801-JZAZL      0              0  ...          29.60       346.45      0
# 7041  8361-LTMKD      1              1  ...          74.40        306.6      1
# 7042  3186-AJIEK      1              0  ...         105.65       6844.5      0
#
# [7043 rows x 21 columns]

# %%
churn_df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_df.replace(r'^\s*$', np.nan, regex=True).isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
churn_df = churn_df.replace(r'^\s*$', np.nan, regex=True)

# %%
churn_df.dtypes
# Out:
# customerID           object
# gender              float64
# SeniorCitizen         int64
# Partner             float64
# Dependents          float64
# tenure                int64
# PhoneService        float64
# MultipleLines       float64
# InternetService     float64
# OnlineSecurity      float64
# OnlineBackup        float64
# DeviceProtection    float64
# TechSupport         float64
# StreamingTV         float64
# StreamingMovies     float64
# Contract            float64
# PaperlessBilling    float64
# PaymentMethod       float64
# MonthlyCharges      float64
# TotalCharges        float64
# Churn               float64
# dtype: object

# %%
churn_df.iloc[:, 19] = pd.to_numeric(churn_df.iloc[:, 19], errors='coerce')

# %%
from sklearn.impute import SimpleImputer
imp_median = SimpleImputer(missing_values=np.nan, strategy='median')

# %%
churn_df.iloc[:, 19] = imp_median.fit_transform(churn_df.iloc[:, 19].values.reshape(-1, 1) )

# %%
churn_df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
churn_df_X = churn_df.drop("Churn", axis=1)
churn_df_X = churn_df_X.drop("customerID", axis=1)
churn_df_y = churn_df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(churn_df_X, churn_df_y, train_size=0.75, test_size=0.25)

# %%
X_train
# Out:
#       gender  SeniorCitizen  ...  MonthlyCharges  TotalCharges
# 6000     1.0              0  ...           19.65        928.40
# 434      1.0              0  ...           19.75        899.45
# 2083     0.0              0  ...           20.15         20.15
# 1091     1.0              0  ...           75.35       2243.90
# 4878     1.0              0  ...           59.05       1882.80
# ...      ...            ...  ...             ...           ...
# 1466     1.0              0  ...           49.20        571.15
# 2602     0.0              0  ...          111.45       7266.95
# 4155     0.0              1  ...          117.35       8436.25
# 6718     1.0              0  ...           75.00        209.10
# 3763     1.0              0  ...           80.35        307.40
#
# [5282 rows x 19 columns]

# %% [markdown]
# **Use TPOT classifier to find the best model algorithm that fits the data. TPOT uses genetic algorithm based search internally**

# %%
tpot =  TPOTClassifier(generations=4, population_size=10, verbosity=3)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
# Out:
# 31 operators have been imported by TPOT.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=50.0, style=ProgressStyle(des…
# Generation 1 - Current Pareto front scores:
# -1	0.7993115225983846	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=17, RandomForestClassifier__min_samples_split=11, RandomForestClassifier__n_estimators=100)
#
# _pre_test decorator: _random_mutation_operator: num_test=0 feature_names mismatch: ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges'] ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18']
# expected gender, tenure, OnlineSecurity, TotalCharges, StreamingMovies, Partner, MonthlyCharges, TechSupport, StreamingTV, OnlineBackup, MultipleLines, DeviceProtection, Contract, InternetService, PaperlessBilling, Dependents, PhoneService, PaymentMethod, SeniorCitizen in input data
# training data did not have the following fields: f10, f12, f17, f0, f4, f6, f11, f3, f7, f9, f2, f1, f8, f14, f16, f5, f13, f15, f18.
# Generation 2 - Current Pareto front scores:
# -1	0.7993115225983846	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.2, RandomForestClassifier__min_samples_leaf=17, RandomForestClassifier__min_samples_split=11, RandomForestClassifier__n_estimators=100)
#
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 98.
# Generation 3 - Current Pareto front scores:
# -1	0.8002574182276451	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.35000000000000003, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=20, RandomForestClassifier__n_estimators=100)
#
# Generation 4 - Current Pareto front scores:
# -1	0.8002574182276451	RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.35000000000000003, RandomForestClassifier__min_samples_leaf=10, RandomForestClassifier__min_samples_split=20, RandomForestClassifier__n_estimators=100)
#
# 0.8069278818852924

# %%
import multiprocessing

if __name__ == '__main__':
    multiprocessing.set_start_method('forkserver', force=True)
    tpot =  TPOTClassifier(generations=4, population_size=10, verbosity=3,n_jobs = 20)
    tpot.fit(X_train, y_train)
# Out:
# 31 operators have been imported by TPOT.
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=50.0, style=ProgressStyle(des…
# _pre_test decorator: _random_mutation_operator: num_test=0 Found array with 0 feature(s) (shape=(50, 0)) while a minimum of 1 is required..
# Generation 1 - Current Pareto front scores:
# -1	0.7996956808157186	LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)
#
# _pre_test decorator: _random_mutation_operator: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 86.
# Generation 2 - Current Pareto front scores:
# -1	0.7996956808157186	LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)
#
# Generation 3 - Current Pareto front scores:
# -1	0.7996956808157186	LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)
#
# _pre_test decorator: _random_mutation_operator: num_test=0 '(slice(None, None, None), 0)' is an invalid key.
# Generation 4 - Current Pareto front scores:
# -1	0.7996956808157186	LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)

# %%
print(tpot.score(X_test, y_test))
# Out:
# 0.8120386144236229

# %% [markdown]
# **Export the scikit learn code for best classifier and dispay the code**

# %%
tpot.export('tpot_churn_pipeline.py')

# %%
# !cat tpot_churn_pipeline.py
# Out:
# import numpy as np
# import pandas as pd
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split
#
# # NOTE: Make sure that the outcome column is labeled 'target' in the data file
# tpot_data = pd.read_csv('PATH/TO/DATA/FILE', sep='COLUMN_SEPARATOR', dtype=np.float64)
# features = tpot_data.drop('target', axis=1)
# training_features, testing_features, training_target, testing_target = \
#             train_test_split(features, tpot_data['target'], random_state=None)
#
# # Average CV score on the training set was: 0.7996956808157186
# exported_pipeline = LogisticRegression(C=20.0, dual=False, penalty="l2")
#
# exported_pipeline.fit(training_features, training_target)
# results = exported_pipeline.predict(testing_features)

# %% [markdown]
# **Get details on algorithm TPOT searched for and how the performed on the dataset**

# %%
tpot.evaluated_individuals_
# Out:
# {'BernoulliNB(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7521789253594546,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('BernoulliNB(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.55, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)',)},
#  'BernoulliNB(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.55, ExtraTreesClassifier__min_samples_leaf=19, ExtraTreesClassifier__min_samples_split=2, ExtraTreesClassifier__n_estimators=100), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7665642722117203,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7476366930171279,
#   'mutation_count': 3,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'ExtraTreesClassifier(StandardScaler(StandardScaler(input_matrix)), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=10, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7826523744056825,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('ExtraTreesClassifier(StandardScaler(input_matrix), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=10, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)',)},
#  'ExtraTreesClassifier(StandardScaler(input_matrix), ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.05, ExtraTreesClassifier__min_samples_leaf=10, ExtraTreesClassifier__min_samples_split=13, ExtraTreesClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7801891791258522,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'GaussianNB(MaxAbsScaler(DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=3, DecisionTreeClassifier__min_samples_split=5)))': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7718662284470412,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('GaussianNB(MaxAbsScaler(input_matrix))',)},
#  'GaussianNB(MaxAbsScaler(input_matrix))': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.751801211548376,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'GaussianNB(input_matrix)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7500973821389701,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('GaussianNB(MaxAbsScaler(input_matrix))',)},
#  'GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=1.0, GradientBoostingClassifier__max_depth=10, GradientBoostingClassifier__max_features=0.7500000000000001, GradientBoostingClassifier__min_samples_leaf=2, GradientBoostingClassifier__min_samples_split=14, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.7000000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6523819241564988,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l1)',)},
#  'LinearSVC(StandardScaler(input_matrix), LinearSVC__C=15.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=1e-05)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7976109153921064,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 2,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7976119894598155,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',
#    'LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)')},
#  'LogisticRegression(BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7966650197628458,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(Binarizer(SelectFwe(input_matrix, SelectFwe__alpha=0.033), Binarizer__threshold=0.0), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7811393710259495,
#   'mutation_count': 2,
#   'operator_count': 3,
#   'predecessor': ('LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(Binarizer(input_matrix, Binarizer__threshold=1.0), LogisticRegression__C=15.0, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7750837772813199,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'LogisticRegression(KNeighborsClassifier(input_matrix, KNeighborsClassifier__n_neighbors=40, KNeighborsClassifier__p=1, KNeighborsClassifier__weights=distance), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7885214383914763,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(LinearSVC(input_matrix, LinearSVC__C=20.0, LinearSVC__dual=True, LinearSVC__loss=hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.1), LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7834099501632583,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(Normalizer(input_matrix, Normalizer__norm=l2), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7671306639170534,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.7000000000000001, RandomForestClassifier__min_samples_leaf=15, RandomForestClassifier__min_samples_split=6, RandomForestClassifier__n_estimators=100), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7951498682476943,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(SelectFwe(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=entropy, RFE__ExtraTreesClassifier__max_features=0.05, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.55), SelectFwe__alpha=0.033), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.794201108437876,
#   'mutation_count': 2,
#   'operator_count': 3,
#   'predecessor': ('LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.011), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7970438076416337,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l1)': {'crossover_count': 2,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7962869479291974,
#   'mutation_count': 4,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',
#    'LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l1)')},
#  'LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7991267829523973,
#   'mutation_count': 3,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',
#    'LogisticRegression(input_matrix, LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)')},
#  'LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=25.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 2,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7983695652173913,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=25.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',
#    'LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)')},
#  'LogisticRegression(SelectFwe(input_matrix, SelectFwe__alpha=0.033), LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7983695652173913,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(StandardScaler(RFE(input_matrix, RFE__ExtraTreesClassifier__criterion=entropy, RFE__ExtraTreesClassifier__max_features=0.45, RFE__ExtraTreesClassifier__n_estimators=100, RFE__step=0.45)), LogisticRegression__C=0.01, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7913605573695366,
#   'mutation_count': 2,
#   'operator_count': 3,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.01, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(StandardScaler(StandardScaler(input_matrix)), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7978017414217792,
#   'mutation_count': 1,
#   'operator_count': 3,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.01, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7983695652173912,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7978017414217792,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)',
#    'LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)')},
#  'LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7978017414217792,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'LogisticRegression(VarianceThreshold(StandardScaler(input_matrix), VarianceThreshold__threshold=0.005), LogisticRegression__C=0.01, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7983695652173912,
#   'mutation_count': 2,
#   'operator_count': 3,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.01, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.1), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7983681331271123,
#   'mutation_count': 3,
#   'operator_count': 2,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l1)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7328664719023887,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7834099501632583,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l1)',
#    'LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)')},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7995059288537549,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7094238700807699,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(StandardScaler(input_matrix), LogisticRegression__C=0.1, LogisticRegression__dual=True, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l1)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7995070029214641,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=20.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7996956808157186,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=25.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7993168929369308,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=0.0001, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=25.0, LogisticRegression__dual=True, LogisticRegression__penalty=l2)': {'crossover_count': 1,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.6532207710374062,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('LogisticRegression(input_matrix, LogisticRegression__C=25.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)',)},
#  'LogisticRegression(input_matrix, LogisticRegression__C=5.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7995062868763247,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'RandomForestClassifier(Nystroem(input_matrix, Nystroem__gamma=0.5, Nystroem__kernel=additive_chi2, Nystroem__n_components=8), RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.55, RandomForestClassifier__min_samples_leaf=12, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7801924013289797,
#   'mutation_count': 1,
#   'operator_count': 2,
#   'predecessor': ('RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.55, RandomForestClassifier__min_samples_leaf=12, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)',)},
#  'RandomForestClassifier(StandardScaler(input_matrix), RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.7500000000000001, RandomForestClassifier__min_samples_leaf=5, RandomForestClassifier__min_samples_split=5, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7951470040671363,
#   'mutation_count': 0,
#   'operator_count': 2,
#   'predecessor': ('ROOT',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.55, RandomForestClassifier__min_samples_leaf=12, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 0,
#   'internal_cv_score': 0.7966614395371485,
#   'mutation_count': 0,
#   'operator_count': 1,
#   'predecessor': ('ROOT',)},
#  'RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.9500000000000001, RandomForestClassifier__min_samples_leaf=12, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7822757346623131,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.55, RandomForestClassifier__min_samples_leaf=12, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)',)},
#  'XGBClassifier(BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.9500000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7923082431116458,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.9500000000000001)',)},
#  'XGBClassifier(Normalizer(input_matrix, Normalizer__norm=l1), XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.9500000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7960918256286876,
#   'mutation_count': 2,
#   'operator_count': 2,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.9500000000000001)',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=2, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.9500000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7868229793206164,
#   'mutation_count': 2,
#   'operator_count': 1,
#   'predecessor': ('XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.9500000000000001)',)},
#  'XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=8, XGBClassifier__min_child_weight=16, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.9500000000000001)': {'crossover_count': 0,
#   'generation': 'INVALID',
#   'internal_cv_score': 0.7981780231425789,
#   'mutation_count': 1,
#   'operator_count': 1,
#   'predecessor': ('RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.55, RandomForestClassifier__min_samples_leaf=12, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)',)}}

# %%
tpot.fitted_pipeline_
# Out:
# Pipeline(memory=None,
#          steps=[('logisticregression',
#                  LogisticRegression(C=20.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='warn', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)
