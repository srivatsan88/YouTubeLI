# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/Keras_OCR_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Original Repo - https://github.com/faustomorales/keras-ocr

# %%
# !pip install git+https://github.com/srivatsan88/keras-ocr.git#egg=keras-ocr

# %%
import matplotlib.pyplot as plt
import keras_ocr

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...

# %%
images = [
    keras_ocr.tools.read(images) for images in [
        'https://i.pinimg.com/originals/90/e0/b1/90e0b16039dacc8c318c5bf1642495c4.png',
        'https://storage.googleapis.com/kagglesdsdata/datasets%2F38019%2F306654%2Fsamples%2F25egp.png?GoogleAccessId=databundle-worker-v2@kaggle-161607.iam.gserviceaccount.com&Expires=1597934953&Signature=tyyQkFzU8NXd7kpXTGHouPlXrMOVQCNNUjaqiEAnsELs%2BvdWebyOpzKsWkw7WsIZ%2Fl1XeTqZNLs7yolVqa3qe3nbBcknLGjxkQYwaLUeBiVOK50CmtZ9K2Pi%2FlU%2BBV7lydFuQAkO75V47onVQLFk0wKq3qysALIhAWOzXdVukGkvWL7bwk1I%2BY8W8CMoVYsjSrA6wqwbwiBkLOXoQy8WHhU995rcNnSxSgCwNv9ys9Tu9zRCG9KuMXkUBxj%2FdEw%2Fm0LMwUAz%2FxNp9JWznCHJvun6gkLk8KwYaG%2BwgQKF5Gmm4uL7v4kHpqCxpnY0ZdRnd8asRsdif%2BBmyBNkVC8pPg%3D%3D'
    ]
]

# %%
# %%html
# <img src='https://i.pinimg.com/originals/90/e0/b1/90e0b16039dacc8c318c5bf1642495c4.png' />
# Out:
# <img src='https://i.pinimg.com/originals/90/e0/b1/90e0b16039dacc8c318c5bf1642495c4.png' />

# %%
# %%html
# <img src='https://storage.googleapis.com/kagglesdsdata/datasets%2F38019%2F306654%2Fsamples%2F25egp.png?GoogleAccessId=databundle-worker-v2@kaggle-161607.iam.gserviceaccount.com&Expires=1597934953&Signature=tyyQkFzU8NXd7kpXTGHouPlXrMOVQCNNUjaqiEAnsELs%2BvdWebyOpzKsWkw7WsIZ%2Fl1XeTqZNLs7yolVqa3qe3nbBcknLGjxkQYwaLUeBiVOK50CmtZ9K2Pi%2FlU%2BBV7lydFuQAkO75V47onVQLFk0wKq3qysALIhAWOzXdVukGkvWL7bwk1I%2BY8W8CMoVYsjSrA6wqwbwiBkLOXoQy8WHhU995rcNnSxSgCwNv9ys9Tu9zRCG9KuMXkUBxj%2FdEw%2Fm0LMwUAz%2FxNp9JWznCHJvun6gkLk8KwYaG%2BwgQKF5Gmm4uL7v4kHpqCxpnY0ZdRnd8asRsdif%2BBmyBNkVC8pPg%3D%3D' />
# Out:
# <img src='https://storage.googleapis.com/kagglesdsdata/datasets%2F38019%2F306654%2Fsamples%2F25egp.png?GoogleAccessId=databundle-worker-v2@kaggle-161607.iam.gserviceaccount.com&Expires=1597934953&Signature=tyyQkFzU8NXd7kpXTGHouPlXrMOVQCNNUjaqiEAnsELs%2BvdWebyOpzKsWkw7WsIZ%2Fl1XeTqZNLs7yolVqa3qe3nbBcknLGjxkQYwaLUeBiVOK50CmtZ9K2Pi%2FlU%2BBV7lydFuQAkO75V47onVQLFk0wKq3qysALIhAWOzXdVukGkvWL7bwk1I%2BY8W8CMoVYsjSrA6wqwbwiBkLOXoQy8WHhU995rcNnSxSgCwNv9ys9Tu9zRCG9KuMXkUBxj%2FdEw%2Fm0LMwUAz%2FxNp9JWznCHJvun6gkLk8KwYaG%2BwgQKF5Gmm4uL7v4kHpqCxpnY0ZdRnd8asRsdif%2BBmyBNkVC8pPg%3D%3D' />

# %%
prediction = pipeline.recognize(images)

# %%
prediction
# Out:
# [[('walmart', array([[ 61.060547,  21.550781],
#           [381.92773 ,  21.550781],
#           [381.92773 ,  88.59766 ],
#           [ 61.060547,  88.59766 ]], dtype=float32)),
#   ('save', array([[ 58.666016,  95.78125 ],
#           [122.12109 ,  95.78125 ],
#           [122.12109 , 119.72656 ],
#           [ 58.666016, 119.72656 ]], dtype=float32)),
#   ('live', array([[231.07227,  95.78125],
#           [287.34375,  95.78125],
#           [287.34375, 119.72656],
#           [231.07227, 119.72656]], dtype=float32)),
#   ('better', array([[292.1328 ,  95.78125],
#           [383.125  ,  95.78125],
#           [383.125  , 119.72656],
#           [292.1328 , 119.72656]], dtype=float32)),
#   ('money', array([[128.75381 ,  94.62781 ],
#           [226.33899 , 101.24376 ],
#           [224.66411 , 125.948105],
#           [127.07893 , 119.33215 ]], dtype=float32)),
#   ('815', array([[184.3789 , 132.89648],
#           [223.88867, 132.89648],
#           [223.88867, 149.6582 ],
# ...

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)

# %%
detector = keras_ocr.detection.Detector()
recognizer = keras_ocr.recognition.Recognizer(weights='captcha')

pipeline = keras_ocr.pipeline.Pipeline(detector=detector,recognizer=recognizer)
prediction = pipeline.recognize(images)
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/captcha.hdf5
# ...

# %%
prediction
# Out:
# [[('fdd7fndfc', array([[ 61.060547,  21.550781],
#           [381.92773 ,  21.550781],
#           [381.92773 ,  88.59766 ],
#           [ 61.060547,  88.59766 ]], dtype=float32)),
#   ('527c', array([[ 58.666016,  95.78125 ],
#           [122.12109 ,  95.78125 ],
#           [122.12109 , 119.72656 ],
#           [ 58.666016, 119.72656 ]], dtype=float32)),
#   ('c7we', array([[231.07227,  95.78125],
#           [287.34375,  95.78125],
#           [287.34375, 119.72656],
#           [231.07227, 119.72656]], dtype=float32)),
#   ('beffef', array([[292.1328 ,  95.78125],
#           [383.125  ,  95.78125],
#           [383.125  , 119.72656],
#           [292.1328 , 119.72656]], dtype=float32)),
#   ('mcmn8y', array([[128.75381 ,  94.62781 ],
#           [226.33899 , 101.24376 ],
#           [224.66411 , 125.948105],
#           [127.07893 , 119.33215 ]], dtype=float32)),
#   ('8235', array([[184.3789 , 132.89648],
#           [223.88867, 132.89648],
#           [223.88867, 149.6582 ],
# ...

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
