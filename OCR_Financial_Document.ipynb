# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/OCR_Financial_Document.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr

# %%
# !wget https://i.pinimg.com/564x/ee/40/7e/ee407ede9d8e0d4d869f8d3e81d1b28d.jpg
# Out:
# --2020-08-12 02:33:45--  https://i.pinimg.com/564x/ee/40/7e/ee407ede9d8e0d4d869f8d3e81d1b28d.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 88.221.165.28, 2a02:26f0:fe00:288::1931, 2a02:26f0:fe00:2b7::1931, ...
# Connecting to i.pinimg.com (i.pinimg.com)|88.221.165.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40003 (39K) [image/jpeg]
# Saving to: ‘ee407ede9d8e0d4d869f8d3e81d1b28d.jpg’
#
# ee407ede9d8e0d4d869 100%[===================>]  39.07K  --.-KB/s    in 0.08s
#
# 2020-08-12 02:33:45 (515 KB/s) - ‘ee407ede9d8e0d4d869f8d3e81d1b28d.jpg’ saved [40003/40003]

# %%
import easyocr
reader = easyocr.Reader(['en'])
# Out:
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open("ee407ede9d8e0d4d869f8d3e81d1b28d.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=437x709 at 0x7FD730593160>

# %%
bounds = reader.readtext('ee407ede9d8e0d4d869f8d3e81d1b28d.jpg')
bounds
# Out:
# [([[132, 22], [308, 22], [308, 46], [132, 46]],
#   'INCOME STATEMENT',
#   0.1829470545053482),
#  ([[165, 45], [323, 45], [323, 61], [165, 61]],
#   'ears Ending December 31, 2017',
#   0.16671182215213776),
#  ([[119, 47], [157, 47], [157, 59], [119, 59]], 'For the', 0.7225100994110107),
#  ([[59, 77], [127, 77], [127, 91], [59, 91]], 'REVEIUES:', 0.5075967311859131),
#  ([[59, 93], [147, 93], [147, 107], [59, 107]],
#   'Sales Revenue',
#   0.5454458594322205),
#  ([[287, 93], [343, 93], [343, 107], [287, 107]],
#   '$5a0,000',
#   0.04172198474407196),
#  ([[59, 109], [145, 109], [145, 125], [59, 125]],
#   'Other Revenue',
#   0.7976095080375671),
#  ([[325, 109], [343, 109], [343, 123], [325, 123]], '0', 0.31171146035194397),
#  ([[59, 125], [177, 125], [177, 139], [59, 139]],
#   'lLess Sales Returns',
#   0.08367352932691574),
#  ([[187, 125], [253, 125], [253, 139], [187, 139]],
#   'Allgiances',
#   0.16665677726268768),
#  ([[59, 141], [165, 141], [165, 155], [59, 155]],
#   'TOTAL REVEIUES',
#   0.3292025625705719),
#  ([[287, 141], [343, 141], [343, 155], [287, 155]],
#   '$5o0,000',
#   0.5065862536430359),
#  ([[59, 173], [171, 173], [171, 187], [59, 187]],
#   'cost of Gogds Sold',
#   0.01576649211347103),
#  ([[295, 173], [343, 173], [343, 189], [295, 189]],
#   '150,000',
#   0.7714618444442749),
#  ([[59, 187], [147, 187], [147, 203], [59, 203]],
#   'GROSS PROFIT',
#   0.3118234872817993),
#  ([[287, 189], [343, 189], [343, 203], [287, 203]],
#   '$350,000',
#   0.8027200102806091),
#  ([[59, 221], [127, 221], [127, 235], [59, 235]],
#   'EXPEIISES:',
#   0.6120641231536865),
#  ([[58, 235], [123, 235], [123, 253], [58, 253]],
#   'Accounting',
#   0.9745227694511414),
#  ([[301, 237], [343, 237], [343, 253], [301, 253]],
#   '$2,500',
#   0.7059235572814941),
#  ([[59, 253], [123, 253], [123, 269], [59, 269]],
#   'Advertising',
#   0.8437270522117615),
#  ([[301, 253], [343, 253], [343, 267], [301, 267]],
#   '25,000',
#   0.7886814475059509),
#  ([[59, 269], [129, 269], [129, 283], [59, 283]],
#   'Amartizatian',
#   0.30817946791648865),
#  ([[59, 285], [115, 285], [115, 299], [59, 299]],
#   'Dad Debt',
#   0.10859054327011108),
#  ([[309, 285], [343, 285], [343, 299], [309, 299]],
#   '1uuu',
#   0.14044208824634552),
#  ([[59, 301], [133, 301], [133, 317], [59, 317]],
#   'Depreciation',
#   0.6214820146560669),
#  ([[301, 301], [343, 301], [343, 315], [301, 315]],
#   '5u,000',
#   0.012032002210617065),
#  ([[58, 315], [181, 315], [181, 334], [58, 334]],
#   'Employee Payroll Tax',
#   0.18497666716575623),
#  ([[301, 317], [343, 317], [343, 331], [301, 331]],
#   '15,000',
#   0.8219591379165649),
#  ([[59, 332], [159, 332], [159, 350], [59, 350]],
#   'Employee Wages',
#   0.23078933358192444),
#  ([[295, 333], [343, 333], [343, 347], [295, 347]],
#   '1gu,uuu',
#   0.009200271219015121),
#  ([[59, 349], [141, 349], [141, 363], [59, 363]],
#   'Entertainment',
#   0.36637309193611145),
#  ([[59, 365], [117, 365], [117, 379], [59, 379]],
#   'Insurance',
#   0.9672301411628723),
#  ([[309, 365], [343, 365], [343, 381], [309, 381]],
#   '2,000',
#   0.7585948705673218),
#  ([[58, 380], [155, 380], [155, 398], [58, 398]],
#   'Interest Expense',
#   0.9208929538726807),
#  ([[301, 381], [343, 381], [343, 395], [301, 395]],
#   '12,000',
#   0.6670690178871155),
#  ([[59, 397], [143, 397], [143, 411], [59, 411]],
#   'Iiscellanegus',
#   0.16501551866531372),
#  ([[309, 397], [343, 397], [343, 411], [309, 411]],
#   '5,uu0',
#   0.1780528724193573),
#  ([[59, 413], [91, 413], [91, 427], [59, 427]], 'Rent', 0.9807934761047363),
#  ([[301, 413], [343, 413], [343, 427], [301, 427]],
#   '24,000',
#   0.474887877702713),
#  ([[59, 429], [111, 429], [111, 443], [59, 443]],
#   'Saflware',
#   0.2142118513584137),
#  ([[59, 445], [121, 445], [121, 461], [59, 461]],
#   'Telephone',
#   0.6074148416519165),
#  ([[317, 445], [343, 445], [343, 461], [317, 461]],
#   '500',
#   0.21759726107120514),
#  ([[59, 461], [103, 461], [103, 475], [59, 475]],
#   'Utilities',
#   0.8228781819343567),
#  ([[317, 461], [343, 461], [343, 475], [317, 475]],
#   'og0',
#   0.07663563638925552),
#  ([[59, 475], [133, 475], [133, 493], [59, 493]],
#   'Web Hosting',
#   0.9670268297195435),
#  ([[319, 477], [343, 477], [343, 491], [319, 491]],
#   '5u0',
#   0.15916942059993744),
#  ([[59, 492], [153, 492], [153, 510], [59, 510]],
#   'Vehicle Expense',
#   0.8330567479133606),
#  ([[301, 493], [343, 493], [343, 507], [301, 507]],
#   '12,000',
#   0.6770736575126648),
#  ([[59, 573], [165, 573], [165, 587], [59, 587]],
#   'TOTAL EXPEISES',
#   0.34252649545669556),
#  ([[287, 573], [343, 573], [343, 587], [287, 587]],
#   '$258,500',
#   0.851780891418457),
#  ([[59, 605], [221, 605], [221, 619], [59, 619]],
#   'MET IICOME BEFORE TAXES',
#   0.03786889463663101),
#  ([[293, 605], [343, 605], [343, 619], [293, 619]],
#   '$91,500',
#   0.8339670300483704),
#  ([[59, 636], [207, 636], [207, 654], [59, 654]],
#   'Less Income Tax Expense',
#   0.3846311867237091),
#  ([[59, 669], [133, 669], [133, 683], [59, 683]],
#   'MET IICOME',
#   0.14043943583965302),
#  ([[295, 669], [343, 669], [343, 683], [295, 683]],
#   '$91,500',
#   0.6028896570205688)]

# %%
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=437x709 at 0x7FD730593160>

# %%
bounds = reader.readtext('ee407ede9d8e0d4d869f8d3e81d1b28d.jpg', contrast_ths=0.05, adjust_contrast=0.7, add_margin=0.45, width_ths=0.7, decoder='beamsearch')
bounds
# Out:
# [([[125, 15], [315, 15], [315, 53], [125, 53]],
#   'NCOME STATEMENT',
#   0.12464500963687897),
#  ([[160, 40], [328, 40], [328, 66], [160, 66]],
#   'Years Ending December 31, 2017',
#   0.08076101541519165),
#  ([[116, 44], [160, 44], [160, 62], [116, 62]], 'For the', 0.6602461338043213),
#  ([[55, 73], [131, 73], [131, 95], [55, 95]], 'REVENUES:', 0.7365061640739441),
#  ([[55, 89], [151, 89], [151, 111], [55, 111]],
#   'Sales Revenue',
#   0.7544398307800293),
#  ([[283, 89], [347, 89], [347, 111], [283, 111]],
#   '$500,000',
#   0.24289120733737946),
#  ([[54, 104], [150, 104], [150, 130], [54, 130]],
#   'Other Revenue',
#   0.8062742352485657),
#  ([[321, 105], [347, 105], [347, 127], [321, 127]], 's0', 0.20973798632621765),
#  ([[55, 121], [181, 121], [181, 143], [55, 143]],
#   'CLess Sales Returns',
#   0.056820083409547806),
#  ([[183, 121], [257, 121], [257, 143], [183, 143]],
#   ' Allowances',
#   0.6566248536109924),
#  ([[55, 137], [169, 137], [169, 159], [55, 159]],
#   'TOTAL REVENUES',
#   0.5175636410713196),
#  ([[283, 137], [347, 137], [347, 159], [283, 159]],
#   '$500,000',
#   0.5358096957206726),
#  ([[290, 168], [348, 168], [348, 194], [290, 194]],
#   '150,000_',
#   0.42625197768211365),
#  ([[55, 169], [175, 169], [175, 191], [55, 191]],
#   'Cost of Goods Sold',
#   0.29933494329452515),
#  ([[54, 182], [152, 182], [152, 208], [54, 208]],
#   'GROSS PROFIT',
#   0.7292748093605042),
#  ([[283, 185], [347, 185], [347, 207], [283, 207]],
#   '$350,000',
#   0.33422499895095825),
#  ([[55, 217], [131, 217], [131, 239], [55, 239]],
#   'EXPENSES:',
#   0.9421254396438599),
#  ([[52, 229], [129, 229], [129, 259], [52, 259]],
#   'Accounting',
#   0.815235435962677),
#  ([[296, 232], [348, 232], [348, 258], [296, 258]],
#   '$2,500',
#   0.5331041216850281),
#  ([[54, 248], [128, 248], [128, 274], [54, 274]],
#   'Advertising',
#   0.9258291721343994),
#  ([[297, 249], [347, 249], [347, 271], [297, 271]],
#   '25,000',
#   0.5214332938194275),
#  ([[55, 265], [133, 265], [133, 287], [55, 287]],
#   'Amortization',
#   0.8793953657150269),
#  ([[55, 281], [119, 281], [119, 303], [55, 303]],
#   'Bad Debt',
#   0.7234957218170166),
#  ([[305, 281], [347, 281], [347, 303], [305, 303]],
#   '1,000',
#   0.34298959374427795),
#  ([[54, 296], [138, 296], [138, 322], [54, 322]],
#   'Depreciation',
#   0.9701703786849976),
#  ([[297, 297], [347, 297], [347, 319], [297, 319]],
#   '50,000',
#   0.2833941578865051),
#  ([[52, 309], [187, 309], [187, 340], [52, 340]],
#   'Employee Payroll Tax',
#   0.3685714900493622),
#  ([[297, 313], [347, 313], [347, 335], [297, 335]],
#   '15,000',
#   0.4092744290828705),
#  ([[53, 326], [165, 326], [165, 356], [53, 356]],
#   'Employee Wages',
#   0.7875521183013916),
#  ([[291, 329], [347, 329], [347, 351], [291, 351]],
#   '1o0,000',
#   0.6079109311103821),
#  ([[55, 345], [145, 345], [145, 367], [55, 367]],
#   'Entertainment',
#   0.538748025894165),
#  ([[304, 360], [348, 360], [348, 386], [304, 386]],
#   '2,000',
#   0.5950832366943359),
#  ([[55, 361], [121, 361], [121, 383], [55, 383]],
#   'Insurance',
#   0.9689673185348511),
#  ([[52, 374], [161, 374], [161, 404], [52, 404]],
#   'Interest Expense',
#   0.5503391027450562),
#  ([[297, 377], [347, 377], [347, 399], [297, 399]],
#   '12,000',
#   0.3305867314338684),
#  ([[55, 393], [147, 393], [147, 415], [55, 415]],
#   'Miscellaneous',
#   0.9515666365623474),
#  ([[305, 393], [347, 393], [347, 415], [305, 415]],
#   '5,000',
#   0.8121246099472046),
#  ([[55, 409], [95, 409], [95, 431], [55, 431]], 'Rent', 0.8387840986251831),
#  ([[297, 409], [347, 409], [347, 431], [297, 431]],
#   '24,000',
#   0.5277666449546814),
#  ([[55, 425], [115, 425], [115, 447], [55, 447]],
#   'Software',
#   0.15017834305763245),
#  ([[54, 440], [126, 440], [126, 466], [54, 466]],
#   'Telephone',
#   0.7370133399963379),
#  ([[312, 440], [348, 440], [348, 466], [312, 466]],
#   '2,500',
#   0.4572819173336029),
#  ([[55, 457], [107, 457], [107, 479], [55, 479]],
#   'Utilities',
#   0.7725748419761658),
#  ([[313, 457], [347, 457], [347, 479], [313, 479]],
#   ',o00',
#   0.3825855851173401),
#  ([[53, 469], [139, 469], [139, 499], [53, 499]],
#   'Web Hosting',
#   0.3499308228492737),
#  ([[315, 473], [347, 473], [347, 495], [315, 495]], '500', 0.5395367741584778),
#  ([[53, 486], [159, 486], [159, 516], [53, 516]],
#   'Vehicle Expense',
#   0.564479649066925),
#  ([[297, 489], [347, 489], [347, 511], [297, 511]],
#   '12,000',
#   0.3801918923854828),
#  ([[55, 569], [169, 569], [169, 591], [55, 591]],
#   'TOTAL EXPENSES',
#   0.6852200031280518),
#  ([[283, 569], [347, 569], [347, 591], [283, 591]],
#   '$258,500',
#   0.4047938883304596),
#  ([[55, 601], [225, 601], [225, 623], [55, 623]],
#   'NET INCOME BEFORE TAXES',
#   0.28944844007492065),
#  ([[289, 601], [347, 601], [347, 623], [289, 623]],
#   '$91,500',
#   0.1506083607673645),
#  ([[53, 630], [213, 630], [213, 660], [53, 660]],
#   'Less Income Tax Expense',
#   0.7547332048416138),
#  ([[55, 665], [137, 665], [137, 687], [55, 687]],
#   'NET INCOME',
#   0.6041017174720764),
#  ([[291, 665], [347, 665], [347, 687], [291, 687]],
#   '$91,500_',
#   0.7901979684829712)]

# %%
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=437x709 at 0x7FD730593160>
