# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/dsportfolio/Coronavirus_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Model Training](https://drive.google.com/uc?id=17cUxpbL2eonLzgY0uIVAxmsfMfQF1by2)

# %%
from datetime import date
today = date.today()

d = today.strftime("%m-%d-%y")
print("date =", d)
# Out:
# date = 03-12-20

# %%
cnn_url="https://www.cnn.com/world/live-news/coronavirus-outbreak-{}-intl-hnk/index.html".format(d)

# %%
print(cnn_url)
# Out:
# https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html

# %%
from bs4 import BeautifulSoup
import requests

# %%
html = requests.get(cnn_url).text

# %%
soup = BeautifulSoup(html)
print(soup.title)
# Out:
# <title data-rh="true">Live updates: Coronavirus US travel ban hits 26 European countries - CNN</title>

# %%
import spacy 
  
nlp = spacy.load('en_core_web_sm')

# %%
for link in soup.find_all("h2"):
    
    print("Headline : {}".format(link.text))
    for ent in nlp(link.text).ents: 
      print("\tText : {}, Entity : {}".format(ent.text, ent.label_))
# Out:
# Headline : What you need to know
# Headline : Brazil's president says he expects results from his coronavirus test "in the next hours"
# 	Text : Brazil, Entity : GPE
# 	Text : the next hours, Entity : TIME
# Headline : House plans to move coronavirus bill quickly tonight when an agreement is reached
# 	Text : House, Entity : ORG
# 	Text : tonight, Entity : TIME
# Headline : US Southern Command says there are no reports of coronavirus following Brazilian president's visit
# 	Text : US Southern Command, Entity : ORG
# 	Text : Brazilian, Entity : NORP
# Headline : Head coach of English football club tests positive for coronavirus
# 	Text : English, Entity : NORP
# Headline : Cleveland Cavaliers player donates $100,000 to support staff affected by NBA cancellations
# 	Text : Cleveland Cavaliers, Entity : ORG
# 	Text : 100,000, Entity : MONEY
# 	Text : NBA, Entity : ORG
# Headline : Illinois issues guidance on large-scale gatherings
# 	Text : Illinois, Entity : GPE
# Headline : Smithsonian Museums and National Zoo close to the public
# 	Text : Smithsonian Museums, Entity : PERSON
# 	Text : National Zoo, Entity : ORG
# Headline : School districts across Georgia to close due to the coronavirus
# 	Text : Georgia, Entity : GPE
# Headline : Portugal to close all educational establishments on Monday over coronavirus outbreak
# 	Text : Monday, Entity : DATE

# %%
nbc_url='https://www.nbcnews.com/health/coronavirus'
cnbc_rss_url='https://www.cnbc.com/id/10000108/device/rss/rss.html'

# %%
urls=[cnn_url, nbc_url,cnbc_rss_url]
formats=['html.parser','html.parser','xml']
tags=['h2','h2','description']
website=['CNN', 'NBC','CNBC']

# %%
crawl_len=0
for url in urls:
    print("Crawling web page ..........{}".format(url))
    response = requests.get(url)
    soup = BeautifulSoup(response.content,formats[crawl_len])

    for link in soup.find_all(tags[crawl_len]):

      if(len(link.text.split(" ")) > 4):
        print("Headline : {}".format(link.text))

        entities=[]
        for ent in nlp(link.text).ents: 
          print("\tText : {}, Entity : {}".format(ent.text, ent.label_)) 

    crawl_len=crawl_len+1
# Out:
# Crawling web page ..........https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html
# Headline : What you need to know
# Headline : Arlington National Cemetery will close to visitors beginning Friday
# 	Text : Arlington National Cemetery, Entity : ORG
# 	Text : Friday, Entity : DATE
# Headline : Brazil's president says he expects results from his coronavirus test "in the next hours"
# 	Text : Brazil, Entity : GPE
# 	Text : the next hours, Entity : TIME
# Headline : House plans to move coronavirus bill quickly tonight when an agreement is reached
# 	Text : House, Entity : ORG
# 	Text : tonight, Entity : TIME
# Headline : US Southern Command says there are no reports of coronavirus following Brazilian president's visit
# 	Text : US Southern Command, Entity : ORG
# 	Text : Brazilian, Entity : NORP
# Headline : Head coach of English football club tests positive for coronavirus
# 	Text : English, Entity : NORP
# Headline : Cleveland Cavaliers player donates $100,000 to support staff affected by NBA cancellations
# 	Text : Cleveland Cavaliers, Entity : ORG
# 	Text : 100,000, Entity : MONEY
# 	Text : NBA, Entity : ORG
# Headline : Illinois issues guidance on large-scale gatherings
# 	Text : Illinois, Entity : GPE
# Headline : Smithsonian Museums and National Zoo close to the public
# 	Text : Smithsonian Museums, Entity : PERSON
# 	Text : National Zoo, Entity : ORG
# Headline : School districts across Georgia to close due to the coronavirus
# 	Text : Georgia, Entity : GPE
# Crawling web page ..........https://www.nbcnews.com/health/coronavirus
# Headline : From business to sports to politics, coronavirus reaching into every aspect of daily life
# Headline : One hour, three massive stories. On the other side, a different reality for Americans.
# 	Text : One hour, Entity : TIME
# 	Text : three, Entity : CARDINAL
# 	Text : Americans, Entity : NORP
# Headline : Chart: See the day-by-day size of the coronavirus outbreak
# 	Text : day, Entity : DATE
# Headline : Brazilian official who met Trump at Mar-a-Lago tests positive for coronavirus
# 	Text : Brazilian, Entity : NORP
# 	Text : Trump, Entity : PERSON
# Headline : Staying in due to the coronavirus?  Here's what to stock in your fridge and pantry
# Headline : Cuba confirms first coronavirus cases, tells people to make their own masks
# 	Text : Cuba, Entity : GPE
# 	Text : first, Entity : ORDINAL
# Headline : Coronavirus could 'wreak havoc' on U.S. jails, experts warn
# 	Text : U.S., Entity : GPE
# Headline : Pence says there's been 'irresponsible rhetoric' from people downplaying the coronavirus
# 	Text : Pence, Entity : ORG
# Headline : Coronavirus scammers are seeking to profit off the deadly virus
# Headline : Trump imposes major restrictions on travel from Europe
# 	Text : Trump, Entity : ORG
# 	Text : Europe, Entity : LOC
# Headline : Map: Confirmed coronavirus cases, worldwide
# Headline : NCAA limits March Madness attendance as coronavirus hits U.S. athletics
# 	Text : NCAA, Entity : ORG
# 	Text : March, Entity : DATE
# 	Text : U.S., Entity : GPE
# Headline : Dow enters bear territory, plunging by more than 1,400 points
# 	Text : more than 1,400, Entity : CARDINAL
# Headline : Amid coronavirus spread, health advocates worry Trump's immigration policies put public at risk
# 	Text : Trump, Entity : ORG
# Headline : Asian woman attacked in New York City in possible coronavirus bias crime
# 	Text : Asian, Entity : NORP
# 	Text : New York City, Entity : GPE
# Headline : On Amazon, fake authors and plagiarized books ride wave of coronavirus interest
# 	Text : Amazon, Entity : ORG
# Headline : 'Cataclysm for our economy': Latin Americans brace for coronavirus impact
# 	Text : Cataclysm, Entity : ORG
# 	Text : Latin Americans, Entity : NORP
# Headline : People are coming together across U.S. to support local Chinatowns
# 	Text : U.S., Entity : GPE
# 	Text : Chinatowns, Entity : PERSON
# Headline : New to telecommuting? Here are 8 rules you should follow.
# 	Text : 8, Entity : CARDINAL
# Headline : Store owner charged after homemade spray sanitizer burns youths
# Headline : N.Y. Gov. Cuomo questions low coronavirus test rate
# 	Text : Cuomo, Entity : PERSON
# Headline : 'I don't know when I'll see you again': Coronavirus lockdown separates couple married 58 years
# 	Text : 58 years, Entity : DATE
# Headline : Coronavirus: What you need to know
# Headline : Photos capture empty cities across the globe
# Headline : His team was close to a coronavirus vaccine. Today he told Congress why it's sitting in a freezer.
# 	Text : Today, Entity : DATE
# 	Text : Congress, Entity : ORG
# Headline : Coronavirus patient explains what the illness feels like, conditions in quarantine
# Headline : Coronavirus updates live: U.S. cases top 1,000
# 	Text : U.S., Entity : GPE
# 	Text : 1,000, Entity : CARDINAL
# Headline : New York biotech company works to make antibody treatment for coronavirus
# 	Text : New York, Entity : GPE
# Headline : Couple on Grand Princess cruise ship carrying coronavirus patients sues for $1 million
# 	Text : $1 million, Entity : MONEY
# Headline : The U.S. has tested more than 8,500 specimens for coronavirus. That doesn't equal 8,500 patients.
# 	Text : U.S., Entity : GPE
# 	Text : more than 8,500, Entity : CARDINAL
# 	Text : 8,500, Entity : CARDINAL
# Headline : Carmakers — and car owners — could soon feel the impact of the coronavirus
# Headline : Chinese restaurant chain booting diners with fever amid coronavirus outbreak
# 	Text : Chinese, Entity : NORP
# Headline : Italians wake up to virtual standstill after sweeping quarantine measures announced
# 	Text : Italians, Entity : NORP
# Headline : Coronavirus forces 'Jeopardy!' and 'Wheel of Fortune' to tape without live audience
# 	Text : 'Wheel of Fortune, Entity : WORK_OF_ART
# Headline : As coronavirus spreads, students stuck and isolated in epidemic's epicenter
# Headline : Trump proposes payroll tax cut, other measures to offset coronavirus economic damage
# 	Text : Trump, Entity : ORG
# Headline : Father of coronavirus patient broke quarantine. How can health officials enforce rules?
# Crawling web page ..........https://www.cnbc.com/id/10000108/device/rss/rss.html
# Headline : Latest news for health care.
# Headline : New York's attorney general said Thursday that her office has ordered InfoWar's Alex Jones to immediately stop selling and marketing products as a "cure" or "treatment" for the coronavirus.
# 	Text : New York's, Entity : GPE
# 	Text : Thursday, Entity : DATE
# 	Text : InfoWar, Entity : ORG
# 	Text : Alex Jones, Entity : PERSON
# Headline : Some doctors and nurses lack childcare in regions hard hit by the coronavirus, like Seattle. Schools and some day care centers are closing. But they're needed more than ever as the coronavirus continues its spread.
# 	Text : Seattle, Entity : GPE
# Headline : Unlike employees at Amazon's corporate offices, many fulfillment center employees and delivery drivers cannot carry out their job duties while working from home.
# 	Text : Amazon, Entity : ORG
# Headline : Amazon, like other e-commerce companies, has struggled to police sellers who have sought to take advantage of the panic and flooded online marketplaces with overpriced goods.
# 	Text : Amazon, Entity : ORG
# Headline : Large venues such as Barclays Center and Madison Square Garden will likely be closed for months as officials try to contain the fast-spreading coronavirus.
# 	Text : Barclays Center, Entity : ORG
# 	Text : Madison Square Garden, Entity : FAC
# 	Text : months, Entity : DATE
# Headline : New York City Mayor Bill de Blasio is holding a press conference to update the public on the coronavirus outbreak, which has infected 328 people across the state as of Thursday afternoon.
# 	Text : New York City, Entity : GPE
# 	Text : Bill de Blasio, Entity : PERSON
# 	Text : 328, Entity : CARDINAL
# 	Text : Thursday, Entity : DATE
# 	Text : afternoon, Entity : TIME
# Headline : Trump's European travel restrictions could further strain airlines and drive some of them out of business, a trade group warned.
# 	Text : Trump, Entity : ORG
# 	Text : European, Entity : NORP
# Headline : The mayor of Jersey City, New Jersey, implemented a 10 p.m. curfew Thursday for any of the city's establishments that carry a liquor license.
# 	Text : Jersey City, Entity : GPE
# 	Text : New Jersey, Entity : GPE
# 	Text : 10 p.m., Entity : TIME
# 	Text : Thursday, Entity : DATE
# Headline : "I've said the same thing to you every day for the past three weeks, I think. You are going to see these numbers are going to go up," Cuomo said during a press conference Thursday.
# 	Text : the past three weeks, Entity : DATE
# 	Text : Cuomo, Entity : PERSON
# 	Text : Thursday, Entity : DATE
# Headline : "We have to get this testing back. I hate to keep banging on that, but that is such an important piece because we've got know what we're dealing with," Atlantic Health CEO Brian Gragnolati told CNBC.
# 	Text : Atlantic Health, Entity : ORG
# 	Text : Brian Gragnolati, Entity : PERSON
# 	Text : CNBC, Entity : ORG
# Headline : There are currently at least 328 people confirmed cases in New York, Cuomo said, adding that if the state's actual cases were "10 times that, I would not be surprised."
# 	Text : at least 328, Entity : CARDINAL
# 	Text : New York, Entity : GPE
# 	Text : Cuomo, Entity : ORG
# 	Text : 10, Entity : CARDINAL
# Headline : "Unfortunately this virus laid bare the severe shortcomings of the current administration," Biden said in front of American flags at an event in Delaware.
# 	Text : Biden, Entity : PERSON
# 	Text : American, Entity : NORP
# 	Text : Delaware, Entity : GPE
# Headline : European Central Bank (ECB) President Christine Lagarde told CNBC Thursday that her institution was "fully committed to avoid any fragmentation."
# 	Text : European Central Bank, Entity : ORG
# 	Text : Christine Lagarde, Entity : PERSON
# 	Text : CNBC, Entity : ORG
# 	Text : Thursday, Entity : DATE
# Headline : New York's Metropolitan Museum of Art announced Thursday it is closing to help contain the spread of the coronavirus.
# 	Text : New York's, Entity : GPE
# 	Text : Metropolitan Museum of Art, Entity : ORG
# 	Text : Thursday, Entity : DATE
# Headline : The decision comes amid a flurry of cancellations and safety measures in the sports world.
# Headline : U.K. Prime Minister Boris Johnson announced a change of strategy to tackle the coronavirus outbreak.
# 	Text : U.K., Entity : GPE
# 	Text : Boris Johnson, Entity : PERSON
# Headline : "We are talking about it as a patriotic duty," Ohio Secretary of State Frank LaRose said in an interview. "Part of the reason for this is that the demographic that tends to be our poll workers tends to be older."
# 	Text : Ohio, Entity : GPE
# 	Text : State, Entity : ORG
# 	Text : Frank LaRose, Entity : PERSON
# Headline : Canadian Prime Minister Justin Trudeau is self-isolating at home while his wife, Sophie Gregoire, awaits the results of a test for COVID-19, a spokesperson said Thursday.
# 	Text : Canadian, Entity : NORP
# 	Text : Justin Trudeau, Entity : PERSON
# 	Text : Sophie Gregoire, Entity : PERSON
# 	Text : COVID-19, Entity : PRODUCT
# 	Text : Thursday, Entity : DATE
# Headline : The entire country of Italy is shut down as it attempts to slow the coronavirus outbreak and stem a rising death toll. Here's what it looks like.
# 	Text : Italy, Entity : GPE
# Headline : The organization also canceled "all remaining winter and spring" championships.
# 	Text : winter, Entity : DATE
# Headline : "I would hope within a few weeks we may be able to make an announcement to you all that we've given the first shot to the first person," Dr. Anthony Fauci, director of the National Institute of Allergy and Infectious Diseases, said.
# 	Text : a few weeks, Entity : DATE
# 	Text : first, Entity : ORDINAL
# 	Text : first, Entity : ORDINAL
# 	Text : Anthony Fauci, Entity : PERSON
# 	Text : the National Institute of Allergy and Infectious Diseases, Entity : ORG
# Headline : A top U.S. health official said the country is "not really geared" to conduct the amount of testing for the coronavirus that will be required as the virus continues to spread across the nation.
# 	Text : U.S., Entity : GPE
# Headline : Lagarde suggested that the coronavirus is likely to keep spreading, despite President Donald Trump's travel ban on some European nations.
# 	Text : Donald Trump, Entity : PERSON
# 	Text : European, Entity : NORP
# Headline : The U.S. House Oversight and Reform Committee is continuing its hearing Thursday on the country's preparedness and response to the coronavirus outbreak that has swept across the nation.
# 	Text : The U.S. House, Entity : ORG
# 	Text : Oversight and Reform Committee, Entity : ORG
# 	Text : Thursday, Entity : DATE
# Headline : The Capitol will be closed to the public for the rest of the month, and White House tours will stop indefinitely as officials try to curb the coronavirus pandemic.
# 	Text : Capitol, Entity : ORG
# 	Text : the month, Entity : DATE
# 	Text : White House, Entity : ORG
# Headline : The Canadian e-commerce company told employees to work from home starting March 16.
# 	Text : Canadian, Entity : NORP
# 	Text : March 16, Entity : DATE
# Headline : "They know nothing. We know more than they do, and that's not acceptable either," CNBC's Jim Cramer said.
# 	Text : CNBC, Entity : ORG
# 	Text : Jim Cramer, Entity : PERSON
# Headline : "I didn't think it was a likely outcome," Dallas Mavericks owner Mark Cuban told CNBC on Thursday.
# 	Text : Dallas Mavericks, Entity : GPE
# 	Text : Mark Cuban, Entity : PERSON
# 	Text : CNBC, Entity : ORG
# 	Text : Thursday, Entity : DATE
# Headline : The New York Times' Thomas Friedman said Jeff Bezos and Bill Gates should oversee the efforts to make more test kits and vaccine development.
# 	Text : The New York Times', Entity : ORG
# 	Text : Thomas Friedman, Entity : PERSON
# 	Text : Jeff Bezos, Entity : PERSON
# 	Text : Bill Gates, Entity : PERSON
# Headline : The European Central Bank decided not to cut interest rates, despite market expectations for a reduction amid the ongoing coronavirus outbreak.
# 	Text : The European Central Bank, Entity : ORG

# %%
crawl_len=0
news_dict=[]
for url in urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content,formats[crawl_len])

    for link in soup.find_all(tags[crawl_len]):

      if(len(link.text.split(" ")) > 4):

        entities=[]

        entities=[(ent.text, ent.label_) for ent in nlp(link.text).ents]

        news_dict.append({'website':website[crawl_len],'url': url,'headline':link.text,'entities':entities})
    
    crawl_len=crawl_len+1

# %%
news_dict
# Out:
# [{'entities': [],
#   'headline': 'What you need to know',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('Arlington National Cemetery', 'ORG'), ('Friday', 'DATE')],
#   'headline': 'Arlington National Cemetery will close to visitors beginning Friday',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('Brazil', 'GPE'), ('the next hours', 'TIME')],
#   'headline': 'Brazil\'s president says he expects results from his coronavirus test "in the next hours"',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('House', 'ORG'), ('tonight', 'TIME')],
#   'headline': 'House plans to move coronavirus bill quickly tonight when an agreement is reached',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('US Southern Command', 'ORG'), ('Brazilian', 'NORP')],
#   'headline': "US Southern Command says there are no reports of coronavirus following Brazilian president's visit",
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('English', 'NORP')],
#   'headline': 'Head coach of English football club tests positive for coronavirus',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('Cleveland Cavaliers', 'ORG'),
#    ('100,000', 'MONEY'),
#    ('NBA', 'ORG')],
#   'headline': 'Cleveland Cavaliers player donates $100,000 to support staff affected by NBA cancellations',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('Illinois', 'GPE')],
#   'headline': 'Illinois issues guidance on large-scale gatherings',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('Smithsonian Museums', 'PERSON'), ('National Zoo', 'ORG')],
#   'headline': 'Smithsonian Museums and National Zoo close to the public',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [('Georgia', 'GPE')],
#   'headline': 'School districts across Georgia to close due to the coronavirus',
#   'url': 'https://www.cnn.com/world/live-news/coronavirus-outbreak-03-12-20-intl-hnk/index.html',
#   'website': 'CNN'},
#  {'entities': [],
#   'headline': 'From business to sports to politics, coronavirus reaching into every aspect of daily life',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('One hour', 'TIME'),
#    ('three', 'CARDINAL'),
#    ('Americans', 'NORP')],
#   'headline': 'One hour, three massive stories. On the other side, a different reality for Americans.',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('day', 'DATE')],
#   'headline': 'Chart: See the day-by-day size of the coronavirus outbreak',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Brazilian', 'NORP'), ('Trump', 'PERSON')],
#   'headline': 'Brazilian official who met Trump at Mar-a-Lago tests positive for coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "Staying in due to the coronavirus?  Here's what to stock in your fridge and pantry",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Cuba', 'GPE'), ('first', 'ORDINAL')],
#   'headline': 'Cuba confirms first coronavirus cases, tells people to make their own masks',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('U.S.', 'GPE')],
#   'headline': "Coronavirus could 'wreak havoc' on U.S. jails, experts warn",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Pence', 'ORG')],
#   'headline': "Pence says there's been 'irresponsible rhetoric' from people downplaying the coronavirus",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Coronavirus scammers are seeking to profit off the deadly virus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'ORG'), ('Europe', 'LOC')],
#   'headline': 'Trump imposes major restrictions on travel from Europe',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Map: Confirmed coronavirus cases, worldwide',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('NCAA', 'ORG'), ('March', 'DATE'), ('U.S.', 'GPE')],
#   'headline': 'NCAA limits March Madness attendance as coronavirus hits U.S. athletics',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('more than 1,400', 'CARDINAL')],
#   'headline': 'Dow enters bear territory, plunging by more than 1,400 points',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'ORG')],
#   'headline': "Amid coronavirus spread, health advocates worry Trump's immigration policies put public at risk",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Asian', 'NORP'), ('New York City', 'GPE')],
#   'headline': 'Asian woman attacked in New York City in possible coronavirus bias crime',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Amazon', 'ORG')],
#   'headline': 'On Amazon, fake authors and plagiarized books ride wave of coronavirus interest',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Cataclysm', 'ORG'), ('Latin Americans', 'NORP')],
#   'headline': "'Cataclysm for our economy': Latin Americans brace for coronavirus impact",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('U.S.', 'GPE'), ('Chinatowns', 'PERSON')],
#   'headline': 'People are coming together across U.S. to support local Chinatowns',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('8', 'CARDINAL')],
#   'headline': 'New to telecommuting? Here are 8 rules you should follow.',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Store owner charged after homemade spray sanitizer burns youths',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Cuomo', 'PERSON')],
#   'headline': 'N.Y. Gov. Cuomo questions low coronavirus test rate',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('58 years', 'DATE')],
#   'headline': "'I don't know when I'll see you again': Coronavirus lockdown separates couple married 58 years",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Coronavirus: What you need to know',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Photos capture empty cities across the globe',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Today', 'DATE'), ('Congress', 'ORG')],
#   'headline': "His team was close to a coronavirus vaccine. Today he told Congress why it's sitting in a freezer.",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Coronavirus patient explains what the illness feels like, conditions in quarantine',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('U.S.', 'GPE'), ('1,000', 'CARDINAL')],
#   'headline': 'Coronavirus updates live: U.S. cases top 1,000',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('New York', 'GPE')],
#   'headline': 'New York biotech company works to make antibody treatment for coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('$1 million', 'MONEY')],
#   'headline': 'Couple on Grand Princess cruise ship carrying coronavirus patients sues for $1 million',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('U.S.', 'GPE'),
#    ('more than 8,500', 'CARDINAL'),
#    ('8,500', 'CARDINAL')],
#   'headline': "The U.S. has tested more than 8,500 specimens for coronavirus. That doesn't equal 8,500 patients.",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Carmakers — and car owners — could soon feel the impact of the coronavirus',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Chinese', 'NORP')],
#   'headline': 'Chinese restaurant chain booting diners with fever amid coronavirus outbreak',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Italians', 'NORP')],
#   'headline': 'Italians wake up to virtual standstill after sweeping quarantine measures announced',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [("'Wheel of Fortune", 'WORK_OF_ART')],
#   'headline': "Coronavirus forces 'Jeopardy!' and 'Wheel of Fortune' to tape without live audience",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': "As coronavirus spreads, students stuck and isolated in epidemic's epicenter",
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [('Trump', 'ORG')],
#   'headline': 'Trump proposes payroll tax cut, other measures to offset coronavirus economic damage',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Father of coronavirus patient broke quarantine. How can health officials enforce rules?',
#   'url': 'https://www.nbcnews.com/health/coronavirus',
#   'website': 'NBC'},
#  {'entities': [],
#   'headline': 'Latest news for health care. ',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [("New York's", 'GPE'),
#    ('Thursday', 'DATE'),
#    ('InfoWar', 'ORG'),
#    ('Alex Jones', 'PERSON')],
#   'headline': 'New York\'s attorney general said Thursday that her office has ordered InfoWar\'s Alex Jones to immediately stop selling and marketing products as a "cure" or "treatment" for the coronavirus.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Seattle', 'GPE')],
#   'headline': "Some doctors and nurses lack childcare in regions hard hit by the coronavirus, like Seattle. Schools and some day care centers are closing. But they're needed more than ever as the coronavirus continues its spread.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Amazon', 'ORG')],
#   'headline': "Unlike employees at Amazon's corporate offices, many fulfillment center employees and delivery drivers cannot carry out their job duties while working from home.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Amazon', 'ORG')],
#   'headline': 'Amazon, like other e-commerce companies, has struggled to police sellers who have sought to take advantage of the panic and flooded online marketplaces with overpriced goods.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Barclays Center', 'ORG'),
#    ('Madison Square Garden', 'FAC'),
#    ('months', 'DATE')],
#   'headline': 'Large venues such as Barclays Center and Madison Square Garden will likely be closed for months as officials try to contain the fast-spreading coronavirus.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('New York City', 'GPE'),
#    ('Bill de Blasio', 'PERSON'),
#    ('328', 'CARDINAL'),
#    ('Thursday', 'DATE'),
#    ('afternoon', 'TIME')],
#   'headline': 'New York City Mayor Bill de Blasio is holding a press conference to update the public on the coronavirus outbreak, which has infected 328 people across the state as of Thursday afternoon.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Trump', 'ORG'), ('European', 'NORP')],
#   'headline': "Trump's European travel restrictions could further strain airlines and drive some of them out of business, a trade group warned.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Jersey City', 'GPE'),
#    ('New Jersey', 'GPE'),
#    ('10 p.m.', 'TIME'),
#    ('Thursday', 'DATE')],
#   'headline': "The mayor of Jersey City, New Jersey, implemented a 10 p.m. curfew Thursday for any of the city's establishments that carry a liquor license.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('the past three weeks', 'DATE'),
#    ('Cuomo', 'PERSON'),
#    ('Thursday', 'DATE')],
#   'headline': '"I\'ve said the same thing to you every day for the past three weeks, I think. You are going to see these numbers are going to go up," Cuomo said during a press conference Thursday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Atlantic Health', 'ORG'),
#    ('Brian Gragnolati', 'PERSON'),
#    ('CNBC', 'ORG')],
#   'headline': '"We have to get this testing back. I hate to keep banging on that, but that is such an important piece because we\'ve got know what we\'re dealing with," Atlantic Health CEO Brian Gragnolati told CNBC.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('at least 328', 'CARDINAL'),
#    ('New York', 'GPE'),
#    ('Cuomo', 'ORG'),
#    ('10', 'CARDINAL')],
#   'headline': 'There are currently at least 328 people confirmed cases in New York, Cuomo said, adding that if the state\'s actual cases were "10 times that, I would not be surprised."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Biden', 'PERSON'), ('American', 'NORP'), ('Delaware', 'GPE')],
#   'headline': '"Unfortunately this virus laid bare the severe shortcomings of the current administration," Biden said in front of American flags at an event in Delaware.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('European Central Bank', 'ORG'),
#    ('Christine Lagarde', 'PERSON'),
#    ('CNBC', 'ORG'),
#    ('Thursday', 'DATE')],
#   'headline': 'European Central Bank (ECB) President Christine Lagarde told CNBC Thursday that her institution was "fully committed to avoid any fragmentation."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [("New York's", 'GPE'),
#    ('Metropolitan Museum of Art', 'ORG'),
#    ('Thursday', 'DATE')],
#   'headline': "New York's Metropolitan Museum of Art announced Thursday it is closing to help contain the spread of the coronavirus.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [],
#   'headline': 'The decision comes amid a flurry of cancellations and safety measures in the sports world.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('U.K.', 'GPE'), ('Boris Johnson', 'PERSON')],
#   'headline': 'U.K. Prime Minister Boris Johnson announced a change of strategy to tackle the coronavirus outbreak.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Ohio', 'GPE'), ('State', 'ORG'), ('Frank LaRose', 'PERSON')],
#   'headline': '"We are talking about it as a patriotic duty," Ohio Secretary of State Frank LaRose said in an interview. "Part of the reason for this is that the demographic that tends to be our poll workers tends to be older."',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Canadian', 'NORP'),
#    ('Justin Trudeau', 'PERSON'),
#    ('Sophie Gregoire', 'PERSON'),
#    ('COVID-19', 'PRODUCT'),
#    ('Thursday', 'DATE')],
#   'headline': 'Canadian Prime Minister Justin Trudeau is self-isolating at home while his wife, Sophie Gregoire, awaits the results of a test for COVID-19, a spokesperson said Thursday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Italy', 'GPE')],
#   'headline': "The entire country of Italy is shut down as it attempts to slow the coronavirus outbreak and stem a rising death toll. Here's what it looks like.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('winter', 'DATE')],
#   'headline': 'The organization also canceled "all remaining winter and spring" championships.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('a few weeks', 'DATE'),
#    ('first', 'ORDINAL'),
#    ('first', 'ORDINAL'),
#    ('Anthony Fauci', 'PERSON'),
#    ('the National Institute of Allergy and Infectious Diseases', 'ORG')],
#   'headline': '"I would hope within a few weeks we may be able to make an announcement to you all that we\'ve given the first shot to the first person," Dr. Anthony Fauci, director of the National Institute of Allergy and Infectious Diseases, said.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('U.S.', 'GPE')],
#   'headline': 'A top U.S. health official said the country is "not really geared" to conduct the amount of testing for the coronavirus that will be required as the virus continues to spread across the nation.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Donald Trump', 'PERSON'), ('European', 'NORP')],
#   'headline': "Lagarde suggested that the coronavirus is likely to keep spreading, despite President Donald Trump's travel ban on some European nations.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('The U.S. House', 'ORG'),
#    ('Oversight and Reform Committee', 'ORG'),
#    ('Thursday', 'DATE')],
#   'headline': "The U.S. House Oversight and Reform Committee is continuing its hearing Thursday on the country's preparedness and response to the coronavirus outbreak that has swept across the nation.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Capitol', 'ORG'),
#    ('the month', 'DATE'),
#    ('White House', 'ORG')],
#   'headline': 'The Capitol will be closed to the public for the rest of the month, and White House tours will stop indefinitely as officials try to curb the coronavirus pandemic.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Canadian', 'NORP'), ('March 16', 'DATE')],
#   'headline': 'The Canadian e-commerce company told employees to work from home starting March 16.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('CNBC', 'ORG'), ('Jim Cramer', 'PERSON')],
#   'headline': '"They know nothing. We know more than they do, and that\'s not acceptable either," CNBC\'s Jim Cramer said.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('Dallas Mavericks', 'GPE'),
#    ('Mark Cuban', 'PERSON'),
#    ('CNBC', 'ORG'),
#    ('Thursday', 'DATE')],
#   'headline': '"I didn\'t think it was a likely outcome," Dallas Mavericks owner Mark Cuban told CNBC on Thursday.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [("The New York Times'", 'ORG'),
#    ('Thomas Friedman', 'PERSON'),
#    ('Jeff Bezos', 'PERSON'),
#    ('Bill Gates', 'PERSON')],
#   'headline': "The New York Times' Thomas Friedman said Jeff Bezos and Bill Gates should oversee the efforts to make more test kits and vaccine development.",
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'},
#  {'entities': [('The European Central Bank', 'ORG')],
#   'headline': 'The European Central Bank decided not to cut interest rates, despite market expectations for a reduction amid the ongoing coronavirus outbreak.',
#   'url': 'https://www.cnbc.com/id/10000108/device/rss/rss.html',
#   'website': 'CNBC'}]

# %%
import pandas as pd

# %%
news_df=pd.DataFrame(news_dict)

# %%
pd.set_option('max_colwidth', 800)

news_df.head(20)
# Out:
#    website  ...                                                    entities
# 0      CNN  ...                                                          []
# 1      CNN  ...        [(Arlington National Cemetery, ORG), (Friday, DATE)]
# 2      CNN  ...                     [(Brazil, GPE), (the next hours, TIME)]
# 3      CNN  ...                             [(House, ORG), (tonight, TIME)]
# 4      CNN  ...             [(US Southern Command, ORG), (Brazilian, NORP)]
# 5      CNN  ...                                           [(English, NORP)]
# 6      CNN  ...  [(Cleveland Cavaliers, ORG), (100,000, MONEY), (NBA, ORG)]
# 7      CNN  ...                                           [(Illinois, GPE)]
# 8      CNN  ...        [(Smithsonian Museums, PERSON), (National Zoo, ORG)]
# 9      CNN  ...                                            [(Georgia, GPE)]
# 10     NBC  ...                                                          []
# 11     NBC  ...    [(One hour, TIME), (three, CARDINAL), (Americans, NORP)]
# 12     NBC  ...                                               [(day, DATE)]
# 13     NBC  ...                        [(Brazilian, NORP), (Trump, PERSON)]
# 14     NBC  ...                                                          []
# 15     NBC  ...                             [(Cuba, GPE), (first, ORDINAL)]
# 16     NBC  ...                                               [(U.S., GPE)]
# 17     NBC  ...                                              [(Pence, ORG)]
# 18     NBC  ...                                                          []
# 19     NBC  ...                               [(Trump, ORG), (Europe, LOC)]
#
# [20 rows x 4 columns]

# %%
news_final_df=pd.concat([news_df[['website','url','headline']],news_df['entities'].apply(pd.Series)],axis=1)

# %%
news_final_df.head()
# Out:
#   website  ...    4
# 0     CNN  ...  NaN
# 1     CNN  ...  NaN
# 2     CNN  ...  NaN
# 3     CNN  ...  NaN
# 4     CNN  ...  NaN
#
# [5 rows x 8 columns]

# %%
news_df.to_csv("web_scapping.csv")
