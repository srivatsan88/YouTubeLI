# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/statistics/Statistical_Thinking_Imputing_Missing_Value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The video link of code walkthrough is here - https://www.youtube.com/watch?v=JGv9gaCU0i4

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
churn_master_df = pd.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/churn_data_st.csv')

# %%
churn_df = churn_master_df.copy()

# %%
churn_df.head()
# Out:
#    customerID  SeniorCitizen  tenure  ...  MonthlyCharges TotalCharges Churn
# 0  7590-VHVEG              0       1  ...           29.85        29.85    No
# 1  5575-GNVDE              0      34  ...           56.95      1889.50    No
# 2  3668-QPYBK              0       2  ...           53.85       108.15   Yes
# 3  7795-CFOCW              0      45  ...           42.30      1840.75    No
# 4  9237-HQITU              0       2  ...           70.70       151.65   Yes
#
# [5 rows x 9 columns]

# %% [markdown]
# customerID - Customer ID
#
# SeniorCitizen - Whether the customer is a senior citizen or not (1, 0)
#
# tenure - Number of months the customer has stayed with the company
#
# ServiceCount - Number of services/product customer has availed
#
# Contract - The contract term of the customer (Month-to-month, One year, Two year)
#
# PaperlessBilling - Whether the customer has paperless billing or not (Yes, No)
#
# MonthlyCharges - The amount charged to the customer monthly
#
# TotalCharges - The total amount charged to the customer
#
# Churn - Whether the customer churned or not (Yes or No)

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   tenure            7043 non-null   int64
#  3   ServiceCount      7043 non-null   int64
#  4   Contract          7043 non-null   object
#  5   PaperlessBilling  7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7015 non-null   float64
#  8   Churn             7043 non-null   object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 495.3+ KB

# %%
churn_df.isna().sum()
# Out:
# customerID           0
# SeniorCitizen        0
# tenure               0
# ServiceCount         0
# Contract             0
# PaperlessBilling     0
# MonthlyCharges       0
# TotalCharges        28
# Churn                0
# dtype: int64

# %%
print ("Rows     : " ,churn_df.shape[0])
print ("Columns  : " ,churn_df.shape[1])
print ("\nFeatures : \n" ,churn_df.columns.tolist())
print ("\nMissing values :  ", churn_df.isnull().any())
print ("\nUnique values :  \n",churn_df.nunique())
# Out:
# Rows     :  7043
# Columns  :  9
#
# Features :
#  ['customerID', 'SeniorCitizen', 'tenure', 'ServiceCount', 'Contract', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn']
#
# Missing values :   customerID          False
# SeniorCitizen       False
# tenure              False
# ServiceCount        False
# Contract            False
# PaperlessBilling    False
# MonthlyCharges      False
# TotalCharges         True
# Churn               False
# dtype: bool
#
# Unique values :
#  customerID          7043
# SeniorCitizen          2
# tenure                73
# ServiceCount           9
# Contract               3
# PaperlessBilling       2
# MonthlyCharges      1585
# TotalCharges        6514
# Churn                  2
# dtype: int64

# %%
churn_df[churn_df.isna().any(axis=1)]
# Out:
#       customerID  SeniorCitizen  tenure  ...  MonthlyCharges TotalCharges Churn
# 488   4472-LVYGI              0       0  ...           52.55          NaN    No
# 699   8338-QIUNR              0      72  ...           66.50          NaN    No
# 753   3115-CZMZD              0       0  ...           20.25          NaN    No
# 936   5709-LVOEQ              0       0  ...           80.85          NaN    No
# 939   0347-UBKUZ              0      15  ...           19.90          NaN    No
# 1037  4581-LNWUM              0      13  ...           49.15          NaN    No
# 1082  4367-NUYAO              0       0  ...           25.75          NaN    No
# 1340  1371-DWPAZ              0       0  ...           56.05          NaN    No
# 1541  2429-AYKKO              0      72  ...           19.85          NaN    No
# 1914  5356-CSVSQ              0       3  ...           64.60          NaN    No
# 2593  0962-CQPWQ              0      62  ...           20.30          NaN    No
# 3314  2402-TAIRZ              0      37  ...           80.05          NaN    No
# 3331  7644-OMVMY              0       0  ...           19.85          NaN    No
# 3826  3213-VVOLG              0       0  ...           25.35          NaN    No
# 4036  4054-CUMIA              0      18  ...           20.25          NaN    No
# 4043  3308-JSGML              1      59  ...           64.05          NaN    No
# 4158  8874-EJNSR              0      39  ...           25.20          NaN    No
# 4380  2520-SGTTA              0       0  ...           20.00          NaN    No
# 4816  5906-DVAPM              0      55  ...           75.00          NaN    No
# 4891  8404-GFGCZ              0       4  ...           65.60          NaN    No
# 5218  2923-ARZLG              0       0  ...           19.70          NaN    No
# 5392  2162-FRZAA              0      63  ...           39.35          NaN    No
# 5592  5063-IUOKK              0      13  ...           19.75          NaN    No
# 6363  8778-LMWTJ              0       9  ...           74.85          NaN    No
# 6472  1150-FTQGN              0      60  ...           94.15          NaN    No
# 6584  6340-DACFT              0      50  ...           20.55          NaN    No
# 6670  4075-WKNIU              0       0  ...           73.35          NaN    No
# 6754  2775-SEFEE              0       0  ...           61.90          NaN    No
#
# [28 rows x 9 columns]

# %%
churn_df[churn_df['tenure']==0]
# Out:
#       customerID  SeniorCitizen  tenure  ...  MonthlyCharges TotalCharges Churn
# 488   4472-LVYGI              0       0  ...           52.55          NaN    No
# 753   3115-CZMZD              0       0  ...           20.25          NaN    No
# 936   5709-LVOEQ              0       0  ...           80.85          NaN    No
# 1082  4367-NUYAO              0       0  ...           25.75          NaN    No
# 1340  1371-DWPAZ              0       0  ...           56.05          NaN    No
# 3331  7644-OMVMY              0       0  ...           19.85          NaN    No
# 3826  3213-VVOLG              0       0  ...           25.35          NaN    No
# 4380  2520-SGTTA              0       0  ...           20.00          NaN    No
# 5218  2923-ARZLG              0       0  ...           19.70          NaN    No
# 6670  4075-WKNIU              0       0  ...           73.35          NaN    No
# 6754  2775-SEFEE              0       0  ...           61.90          NaN    No
#
# [11 rows x 9 columns]

# %%
churn_df['TotalCharges'].describe()
# Out:
# count    7015.000000
# mean     2284.315310
# std      2267.765142
# min        18.800000
# 25%       401.400000
# 50%      1398.250000
# 75%      3794.975000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
churn_df[churn_df['Churn']=='No'].describe()
# Out:
#        SeniorCitizen       tenure  ServiceCount  MonthlyCharges  TotalCharges
# count    5174.000000  5174.000000   5174.000000     5174.000000   5146.000000
# mean        0.128721    37.569965      5.811751       61.265124   2557.626312
# std         0.334923    24.113777      1.890418       31.092648   2330.764669
# min         0.000000     0.000000      1.000000       18.250000     18.800000
# 25%         0.000000    15.000000      4.000000       25.100000    578.625000
# 50%         0.000000    38.000000      6.000000       64.425000   1686.025000
# 75%         0.000000    61.000000      7.000000       88.400000   4264.900000
# max         1.000000    72.000000      9.000000      118.750000   8672.450000

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="TotalCharges", y="Churn", data=churn_df)

# %%
sns.distplot(churn_df['TotalCharges'], hist=True)

# %%
sns.distplot(churn_df['TotalCharges'].apply(np.sqrt), hist=True)

# %%
sns.lmplot(x='MonthlyCharges',y='TotalCharges',data=churn_df,fit_reg=True, hue="Churn", markers=["o", "x"], palette="Blues_d")

# %%
sns.lmplot(x='MonthlyCharges',y='TotalCharges',data=churn_df,fit_reg=True, col="Churn", hue="Churn")

# %%
sns.lmplot(x='MonthlyCharges',y='TotalCharges',data=churn_df,fit_reg=True, col="Churn", hue="Churn", line_kws={'color':'red'})

# %%
churn_df[['TotalCharges','MonthlyCharges']].corr()
# Out:
#                 TotalCharges  MonthlyCharges
# TotalCharges        1.000000        0.651136
# MonthlyCharges      0.651136        1.000000

# %%
churn_df[churn_df['Churn']=='No'][['TotalCharges','MonthlyCharges']].corr()
# Out:
#                 TotalCharges  MonthlyCharges
# TotalCharges        1.000000        0.757311
# MonthlyCharges      0.757311        1.000000

# %%
churn_no_df=churn_df[(churn_df['Churn']=='No') & (churn_df['TotalCharges'].isna()==False)]
churn_no_df.shape[0]
# Out:
# 5146

# %%
churn_no_df.isna().any()
# Out:
# customerID          False
# SeniorCitizen       False
# tenure              False
# ServiceCount        False
# Contract            False
# PaperlessBilling    False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err=stats.linregress(churn_no_df['MonthlyCharges'],churn_no_df['TotalCharges'])

# %%
print ("slope     : " ,slope)
print ("intercept  : " ,intercept)
print ("r_value :  " ,r_value)
print ("p_value :  ", p_value)
print ("std_err :  ",std_err)
print("R-squared: ",  r_value**2)
# Out:
# slope     :  56.75211428306715
# intercept  :  -924.1594617231112
# r_value :   0.7573113760322048
# p_value :   0.0
# std_err :   0.6823483644437863
# R-squared:  0.5735205202677914

# %%
ax=sns.regplot(x='MonthlyCharges', y='TotalCharges', data=churn_no_df, line_kws={'color':'red','label':'y={0:.1f}x+{1:.1f}'.format(slope,intercept)})
ax.legend(loc="best")

# %%
sns.lmplot(x='tenure',y='TotalCharges',data=churn_df,fit_reg=True, line_kws={'color':'red'})

# %%
sns.lmplot(x='tenure',y='TotalCharges',data=churn_df,fit_reg=True, col="Churn", hue="Churn", line_kws={'color':'red'})

# %%
churn_df[['TotalCharges','tenure']].corr()
# Out:
#               TotalCharges    tenure
# TotalCharges      1.000000  0.826326
# tenure            0.826326  1.000000

# %%
churn_df[churn_df['Churn']=='No'][['TotalCharges','tenure']].corr()
# Out:
#               TotalCharges    tenure
# TotalCharges      1.000000  0.793595
# tenure            0.793595  1.000000

# %%
slope, intercept, r_value, p_value, std_err=stats.linregress(churn_no_df['tenure'],churn_no_df['TotalCharges'])

# %%
print ("slope     : " ,slope)
print ("intercept  : " ,intercept)
print ("r_value :  " ,r_value)
print ("p_value :  ", p_value)
print ("std_err :  ",std_err)
print("R-squared: ",  r_value**2)
# Out:
# slope     :  76.82924619200716
# intercept  :  -334.93658083521996
# r_value :   0.7935949203718221
# p_value :   0.0
# std_err :   0.8212957699802916
# R-squared:  0.6297928976399587

# %%
ax=sns.regplot(x='tenure', y='TotalCharges', data=churn_no_df, line_kws={'color':'red','label':'y={0:.1f}x+{1:.1f}'.format(slope,intercept)})
ax.legend(loc="best")

# %%
churn_no_df['tenure_charges']=churn_no_df['tenure']*churn_no_df['MonthlyCharges']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
churn_no_df.head()
# Out:
#    customerID  SeniorCitizen  tenure  ...  TotalCharges Churn tenure_charges
# 0  7590-VHVEG              0       1  ...         29.85    No          29.85
# 1  5575-GNVDE              0      34  ...       1889.50    No        1936.30
# 3  7795-CFOCW              0      45  ...       1840.75    No        1903.50
# 6  1452-KIOVK              0      22  ...       1949.40    No        1960.20
# 7  6713-OKOMC              0      10  ...        301.90    No         297.50
#
# [5 rows x 10 columns]

# %%
churn_no_df[churn_no_df['Churn']=='No'][['TotalCharges','tenure_charges']].corr()
# Out:
#                 TotalCharges  tenure_charges
# TotalCharges        1.000000        0.999536
# tenure_charges      0.999536        1.000000

# %%
sns.lmplot(x='tenure_charges',y='TotalCharges',data=churn_no_df)

# %%
slope, intercept, r_value, p_value, std_err=stats.linregress(churn_no_df['tenure_charges'],churn_no_df['TotalCharges'])

# %%
print ("slope     : " ,slope)
print ("intercept  : " ,intercept)
print ("r_value :  " ,r_value)
print ("p_value :  ", p_value)
print ("std_err :  ",std_err)
print("R-squared: ",  r_value**2)
# Out:
# slope     :  1.0001851163629358
# intercept  :  -0.4347902277722824
# r_value :   0.9995362189853295
# p_value :   0.0
# std_err :   0.00042486650354260744
# R-squared:  0.9990726530634886

# %%
ax=sns.regplot(x='tenure_charges', y='TotalCharges', data=churn_no_df, line_kws={'color':'red','label':'y={0:.3f}x+{1:.3f}'.format(slope,intercept)})
ax.legend(loc="best")

# %%
def fillna(tenure, monthlycharge):
  if tenure == 0 :
    totcharges = monthlycharge
  else :
    totcharges = tenure * monthlycharge
    totcharges = intercept+(totcharges*slope)
  return round(totcharges,2)

# %%
churn_df['TotChargeNew'] = churn_df.apply(lambda x: x['TotalCharges'] if not pd.isna(x['TotalCharges']) else fillna(x['tenure'],x['MonthlyCharges']), axis=1)

# %%
churn_df[churn_df.isna().any(axis=1)]
# Out:
#       customerID  SeniorCitizen  tenure  ...  TotalCharges Churn TotChargeNew
# 488   4472-LVYGI              0       0  ...           NaN    No        52.55
# 699   8338-QIUNR              0      72  ...           NaN    No      4788.45
# 753   3115-CZMZD              0       0  ...           NaN    No        20.25
# 936   5709-LVOEQ              0       0  ...           NaN    No        80.85
# 939   0347-UBKUZ              0      15  ...           NaN    No       298.12
# 1037  4581-LNWUM              0      13  ...           NaN    No       638.63
# 1082  4367-NUYAO              0       0  ...           NaN    No        25.75
# 1340  1371-DWPAZ              0       0  ...           NaN    No        56.05
# 1541  2429-AYKKO              0      72  ...           NaN    No      1429.03
# 1914  5356-CSVSQ              0       3  ...           NaN    No       193.40
# 2593  0962-CQPWQ              0      62  ...           NaN    No      1258.40
# 3314  2402-TAIRZ              0      37  ...           NaN    No      2961.96
# 3331  7644-OMVMY              0       0  ...           NaN    No        19.85
# 3826  3213-VVOLG              0       0  ...           NaN    No        25.35
# 4036  4054-CUMIA              0      18  ...           NaN    No       364.13
# 4043  3308-JSGML              1      59  ...           NaN    No      3779.21
# 4158  8874-EJNSR              0      39  ...           NaN    No       982.55
# 4380  2520-SGTTA              0       0  ...           NaN    No        20.00
# 4816  5906-DVAPM              0      55  ...           NaN    No      4125.33
# 4891  8404-GFGCZ              0       4  ...           NaN    No       262.01
# 5218  2923-ARZLG              0       0  ...           NaN    No        19.70
# 5392  2162-FRZAA              0      63  ...           NaN    No      2479.07
# 5592  5063-IUOKK              0      13  ...           NaN    No       256.36
# 6363  8778-LMWTJ              0       9  ...           NaN    No       673.34
# 6472  1150-FTQGN              0      60  ...           NaN    No      5649.61
# 6584  6340-DACFT              0      50  ...           NaN    No      1027.26
# 6670  4075-WKNIU              0       0  ...           NaN    No        73.35
# 6754  2775-SEFEE              0       0  ...           NaN    No        61.90
#
# [28 rows x 10 columns]

# %%
churn_actual_df = pd.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/churn_data_actual.csv')

# %%
churn_merged=pd.merge(churn_df, churn_actual_df)

# %%
churn_merged[churn_merged.isna().any(axis=1)]
# Out:
#       customerID  SeniorCitizen  tenure  ...  Churn TotChargeNew TotChargesAct
# 488   4472-LVYGI              0       0  ...     No        52.55
# 699   8338-QIUNR              0      72  ...     No      4788.45        4811.6
# 753   3115-CZMZD              0       0  ...     No        20.25
# 936   5709-LVOEQ              0       0  ...     No        80.85
# 939   0347-UBKUZ              0      15  ...     No       298.12        320.45
# 1037  4581-LNWUM              0      13  ...     No       638.63         649.4
# 1082  4367-NUYAO              0       0  ...     No        25.75
# 1340  1371-DWPAZ              0       0  ...     No        56.05
# 1541  2429-AYKKO              0      72  ...     No      1429.03        1434.1
# 1914  5356-CSVSQ              0       3  ...     No       193.40         174.2
# 2593  0962-CQPWQ              0      62  ...     No      1258.40       1296.15
# 3314  2402-TAIRZ              0      37  ...     No      2961.96        3019.1
# 3331  7644-OMVMY              0       0  ...     No        19.85
# 3826  3213-VVOLG              0       0  ...     No        25.35
# 4036  4054-CUMIA              0      18  ...     No       364.13        401.95
# 4043  3308-JSGML              1      59  ...     No      3779.21       3886.85
# 4158  8874-EJNSR              0      39  ...     No       982.55        987.95
# 4380  2520-SGTTA              0       0  ...     No        20.00
# 4816  5906-DVAPM              0      55  ...     No      4125.33        4213.9
# 4891  8404-GFGCZ              0       4  ...     No       262.01         250.1
# 5218  2923-ARZLG              0       0  ...     No        19.70
# 5392  2162-FRZAA              0      63  ...     No      2479.07       2395.05
# 5592  5063-IUOKK              0      13  ...     No       256.36        265.75
# 6363  8778-LMWTJ              0       9  ...     No       673.34         708.2
# 6472  1150-FTQGN              0      60  ...     No      5649.61        5811.8
# 6584  6340-DACFT              0      50  ...     No      1027.26       1070.25
# 6670  4075-WKNIU              0       0  ...     No        73.35
# 6754  2775-SEFEE              0       0  ...     No        61.90
#
# [28 rows x 11 columns]
