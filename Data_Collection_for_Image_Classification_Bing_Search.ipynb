# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/Data_Collection_for_Image_Classification_Bing_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading https://files.pythonhosted.org/packages/0d/bf/537a61030b84ae4cd5022d5c7b014fd9bc3ce7c02358919153a6658a61d3/bing_image_downloader-1.0.4-py3-none-any.whl
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.0.4

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("elephant in africa", limit=5,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://messagenote.com/wp-content/uploads/2011/05/Africa-Elephants.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.nrdc.org/sites/default/files/styles/header_background/public/wlds43_654640_900x600.jpg?itok=fRiJVPM1
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://c402277.ssl.cf1.rackcdn.com/photos/12637/images/magazine_medium/Medium_WW22456.jpg?1477667080
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.lifeofpix.com/wp-content/uploads/2017/06/african-bush-elephant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.todayifoundout.com/wp-content/uploads/2014/06/african-elephant-bull.jpg
# [%] File Downloaded !

# %%
downloader.download("kangaroo in australia", limit=5,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://cdn.newsapi.com.au/image/v1/c9c38750fa3fbd99d79a0b732ef5378f
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/animal-of-the-month-the-red-kangaroo/jcr:content/image.adapt.1200.HIGH.jpg
# [Error]Invalid image, not saving http://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/animal-of-the-month-the-red-kangaroo/jcr:content/image.adapt.1200.HIGH.jpg
#
# [!] Issue getting: http://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/animal-of-the-month-the-red-kangaroo/jcr:content/image.adapt.1200.HIGH.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #2 from https://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2018/08/15/Pictures/red-kangaroo-outback-grasslands-in-the-australian_5cd01cb2-a092-11e8-9345-8d51f8ed9678.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://factmontster.com/wp-content/uploads/2016/09/funny-facts-about-australia-kangaroos.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/where-to-see-kangaroos-in-the-wild/jcr:content/image.adapt.1200.HIGH.jpg
# [Error]Invalid image, not saving https://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/where-to-see-kangaroos-in-the-wild/jcr:content/image.adapt.1200.HIGH.jpg
#
# [!] Issue getting: https://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/where-to-see-kangaroos-in-the-wild/jcr:content/image.adapt.1200.HIGH.jpg
# [!] Error:: No active exception to reraise
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #4 from http://cdn.newsapi.com.au/image/v1/c9c38750fa3fbd99d79a0b732ef5378f
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/animal-of-the-month-the-red-kangaroo/jcr:content/image.adapt.1200.HIGH.jpg
# [Error]Invalid image, not saving http://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/animal-of-the-month-the-red-kangaroo/jcr:content/image.adapt.1200.HIGH.jpg
#
# [!] Issue getting: http://www.australia.com/content/australia/en/things-to-do/nature-and-wildlife/animal-of-the-month-the-red-kangaroo/jcr:content/image.adapt.1200.HIGH.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #5 from https://www.hindustantimes.com/rf/image_size_960x540/HT/p2/2018/08/15/Pictures/red-kangaroo-outback-grasslands-in-the-australian_5cd01cb2-a092-11e8-9345-8d51f8ed9678.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 5 images.
#
# ===============================================

# %%
# !ls images/ -alrt
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jul 26 23:13  ..
# drwxr-xr-x 2 root root 4096 Jul 26 23:14 'elephant in africa'
# drwxr-xr-x 4 root root 4096 Jul 26 23:15  .
# drwxr-xr-x 2 root root 4096 Jul 26 23:15 'kangaroo in australia'

# %%
# !ls 'images'/'elephant in africa'
# Out:
# Image_1.jpg  Image_2.jpg  Image_3.jpg  Image_4.jpg  Image_5.jpg

# %%
# !ls 'images'/'kangaroo in australia'
# Out:
# Image_1.jpg  Image_2.jpg  Image_3.jpg  Image_4.jpg  Image_5.jpg

# %%
from IPython.display import Image
Image("images/elephant in africa/Image_5.jpg")

# %%
Image("images/kangaroo in australia/Image_3.jpg")

# %%
from six import BytesIO
from PIL import Image
import numpy as np
import glob
import os

import matplotlib
import matplotlib.pyplot as plt

# %%
def load_image_into_numpy_array(path):
  img_data = open(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

# %%
elephant_image_path = "/content/images/elephant in africa/*"
elephant_images_np = []
for iname in glob.glob(elephant_image_path):
  elephant_images_np.append(load_image_into_numpy_array(iname))

# %%
plt.rcParams['figure.figsize'] = [14, 7]

for idx, elephant_image_np in enumerate(elephant_images_np):
  plt.subplot(2, 3, idx+1)
  plt.imshow(elephant_image_np)
plt.show()
