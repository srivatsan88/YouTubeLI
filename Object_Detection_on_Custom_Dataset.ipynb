# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsan88/YouTubeLI/blob/master/Object_Detection_on_Custom_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1yt3NfCfp7hnXIFfSq1kk8LYKfX_X6Qxq)

# %%
# !nvidia-smi
# Out:
# Sun May 17 13:48:37 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install mxnet-cu101 
# !pip install autogluon

# %%
# !pip install -U ipykernel

# %%
import autogluon as ag
from autogluon import ObjectDetection as task

# %% [markdown]
# https://timebutt.github.io/

# %%
root = '/tmp'
filename_zip = ag.download('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/nfpa.zip',
                        path=root)
filename = ag.unzip(filename_zip, root=root)
# Out:
# Downloading /tmp/nfpa.zip from https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/nfpa.zip...
# VBox(children=(HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=20013), HTML(value=''))), HTML…

# %%
# !ls /tmp/nfpa
# Out:
# Annotations  ImageSets	JPEGImages

# %%
import os
data_root = os.path.join(root, filename)
dataset_train = task.Dataset(data_root, classes=('nfpa',))
# Out:
# >>> create dataset(VOC format)

# %%
Image(os.path.join(data_root,"JPEGImages/pos-101.jpg"))

# %%
from IPython.display import Image
Image(os.path.join(data_root,"JPEGImages/pos-201.jpg"))

# %%
time_limits = 20
epochs = 25
detector = task.fit(dataset_train,
                    num_trials=2,
                    epochs=epochs,
                    lr=ag.Categorical(5e-4, 1e-4),
                    ngpus_per_trial=1,
                    time_limits=time_limits)
# Out:
# Starting Experiments
# Num of Finished Tasks is 0
# Num of Pending Tasks is 2
# Time out (secs) is 20
# scheduler: FIFOScheduler(
# DistributedResourceManager{
# (Remote: Remote REMOTE_ID: 0,
# 	<Remote: 'inproc://172.28.0.2/310/1' processes=1 threads=2, memory=13.65 GB>, Resource: NodeResourceManager(2 CPUs, 1 GPUs))
# })
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Model file not found. Downloading.
# Downloading /root/.mxnet/models/yolo3_mobilenet1.0_coco-66dbbae6.zip from https://apache-mxnet.s3-accelerate.dualstack.amazonaws.com/gluon/models/yolo3_mobilenet1.0_coco-66dbbae6.zip...
# 88993KB [00:02, 43827.82KB/s]
# {'meta_arch': 'yolo3', 'dataset': <autogluon.task.object_detection.dataset.voc.CustomVOCDetection object at 0x7f7f5ee9a2b0>, 'net': 'mobilenet1.0', 'lr': 0.0005, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'num_gpus': 1, 'batch_size': 16, 'split_ratio': 0.8, 'epochs': 25, 'num_workers': 2, 'hybridize': True, 'verbose': False, 'final_fit': False, 'seed': 223, 'data_shape': 416, 'start_epoch': 0, 'transfer': 'coco', 'lr_mode': 'step', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '160,180', 'warmup_lr': 0.0, 'warmup_epochs': 2, 'warmup_iters': 1000, 'warmup_factor': 0.3333333333333333, 'momentum': 0.9, 'wd': 0.0005, 'log_interval': 100, 'save_prefix': 'yolo3_mobilenet1.0_custom', 'save_interval': 10, 'val_interval': 1, 'num_samples': -1, 'no_random_shape': False, 'no_wd': False, 'mixup': False, 'no_mixup_epochs': 20, 'label_smooth': False, 'resume': '', 'syncbn': False, 'reuse_pred_weights': True, 'task_id': 0}
# [Epoch 0] Training cost: 57.391, ObjLoss=269.522,BoxCenterLoss=3.011,BoxScaleLoss=1.822,ClassLoss=0.693
# [Epoch 0] Validation: nfpa=0.4341888273356353 mAP=0.4341888273356353
# [Epoch 1] Training cost: 52.541, ObjLoss=8.201,BoxCenterLoss=2.976,BoxScaleLoss=1.220,ClassLoss=0.443
# [Epoch 1] Validation: nfpa=0.4669489471010232 mAP=0.4669489471010232
# [Epoch 2] Training cost: 53.018, ObjLoss=6.676,BoxCenterLoss=3.004,BoxScaleLoss=1.021,ClassLoss=0.363
# [Epoch 2] Validation: nfpa=0.6332298739048052 mAP=0.6332298739048052
# [Epoch 3] Training cost: 43.764, ObjLoss=4.233,BoxCenterLoss=2.873,BoxScaleLoss=1.127,ClassLoss=0.290
# [Epoch 3] Validation: nfpa=0.6210699234929026 mAP=0.6210699234929026
# [Epoch 4] Training cost: 50.501, ObjLoss=3.511,BoxCenterLoss=2.769,BoxScaleLoss=1.134,ClassLoss=0.239
# [Epoch 4] Validation: nfpa=0.7172020961494646 mAP=0.7172020961494646
# [Epoch 5] Training cost: 45.688, ObjLoss=3.184,BoxCenterLoss=2.730,BoxScaleLoss=0.989,ClassLoss=0.204
# [Epoch 5] Validation: nfpa=0.7675258527550549 mAP=0.7675258527550549
# [Epoch 6] Training cost: 55.686, ObjLoss=3.200,BoxCenterLoss=2.768,BoxScaleLoss=0.932,ClassLoss=0.185
# [Epoch 6] Validation: nfpa=0.7494627967210943 mAP=0.7494627967210943
# [Epoch 7] Training cost: 59.520, ObjLoss=3.156,BoxCenterLoss=2.739,BoxScaleLoss=0.966,ClassLoss=0.141
# [Epoch 7] Validation: nfpa=0.6277689197383847 mAP=0.6277689197383847
# [Epoch 8] Training cost: 53.207, ObjLoss=2.768,BoxCenterLoss=2.629,BoxScaleLoss=1.112,ClassLoss=0.147
# [Epoch 8] Validation: nfpa=0.7300905521227945 mAP=0.7300905521227945
# [Epoch 9] Training cost: 47.824, ObjLoss=2.540,BoxCenterLoss=2.644,BoxScaleLoss=0.950,ClassLoss=0.141
# [Epoch 9] Validation: nfpa=0.5792492671811688 mAP=0.5792492671811688
# [Epoch 10] Training cost: 45.811, ObjLoss=2.675,BoxCenterLoss=2.597,BoxScaleLoss=0.910,ClassLoss=0.122
# [Epoch 10] Validation: nfpa=0.820574706435686 mAP=0.820574706435686
# [Epoch 11] Training cost: 49.155, ObjLoss=2.291,BoxCenterLoss=2.828,BoxScaleLoss=0.948,ClassLoss=0.127
# [Epoch 11] Validation: nfpa=0.8270321386130212 mAP=0.8270321386130212
# [Epoch 12] Training cost: 47.627, ObjLoss=2.334,BoxCenterLoss=2.796,BoxScaleLoss=0.863,ClassLoss=0.101
# [Epoch 12] Validation: nfpa=0.8727901411374883 mAP=0.8727901411374883
# [Epoch 13] Training cost: 51.013, ObjLoss=2.303,BoxCenterLoss=2.714,BoxScaleLoss=0.913,ClassLoss=0.096
# [Epoch 13] Validation: nfpa=0.7975786223900084 mAP=0.7975786223900084
# [Epoch 14] Training cost: 53.756, ObjLoss=2.465,BoxCenterLoss=2.791,BoxScaleLoss=0.727,ClassLoss=0.101
# [Epoch 14] Validation: nfpa=0.8515595145641103 mAP=0.8515595145641103
# [Epoch 15] Training cost: 55.373, ObjLoss=2.045,BoxCenterLoss=2.608,BoxScaleLoss=0.654,ClassLoss=0.085
# [Epoch 15] Validation: nfpa=0.876741011720374 mAP=0.876741011720374
# [Epoch 16] Training cost: 47.927, ObjLoss=2.436,BoxCenterLoss=2.653,BoxScaleLoss=0.715,ClassLoss=0.086
# [Epoch 16] Validation: nfpa=0.8539901593570403 mAP=0.8539901593570403
# [Epoch 17] Training cost: 48.643, ObjLoss=2.099,BoxCenterLoss=2.550,BoxScaleLoss=0.629,ClassLoss=0.079
# [Epoch 17] Validation: nfpa=0.891660576956537 mAP=0.891660576956537
# [Epoch 18] Training cost: 51.959, ObjLoss=2.128,BoxCenterLoss=2.677,BoxScaleLoss=0.670,ClassLoss=0.070
# [Epoch 18] Validation: nfpa=0.8694668182453016 mAP=0.8694668182453016
# [Epoch 19] Training cost: 54.756, ObjLoss=2.088,BoxCenterLoss=2.803,BoxScaleLoss=0.696,ClassLoss=0.079
# [Epoch 19] Validation: nfpa=0.8860720674674165 mAP=0.8860720674674165
# [Epoch 20] Training cost: 54.620, ObjLoss=1.969,BoxCenterLoss=2.577,BoxScaleLoss=0.652,ClassLoss=0.065
# [Epoch 20] Validation: nfpa=0.877737210998703 mAP=0.877737210998703
# [Epoch 21] Training cost: 55.851, ObjLoss=2.112,BoxCenterLoss=2.679,BoxScaleLoss=0.659,ClassLoss=0.071
# [Epoch 21] Validation: nfpa=0.8699402047228133 mAP=0.8699402047228133
# [Epoch 22] Training cost: 52.627, ObjLoss=1.821,BoxCenterLoss=2.572,BoxScaleLoss=0.626,ClassLoss=0.054
# [Epoch 22] Validation: nfpa=0.8454646637351813 mAP=0.8454646637351813
# [Epoch 23] Training cost: 56.177, ObjLoss=1.727,BoxCenterLoss=2.632,BoxScaleLoss=0.574,ClassLoss=0.056
# [Epoch 23] Validation: nfpa=0.8888623296806286 mAP=0.8888623296806286
# [Epoch 24] Training cost: 51.519, ObjLoss=1.627,BoxCenterLoss=2.650,BoxScaleLoss=0.641,ClassLoss=0.059
# [Epoch 24] Validation: nfpa=0.8727396562468707 mAP=0.8727396562468707
# {'meta_arch': 'yolo3', 'dataset': <autogluon.task.object_detection.dataset.voc.CustomVOCDetection object at 0x7f7f5f6a07b8>, 'net': 'mobilenet1.0', 'lr': 0.0001, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'num_gpus': 1, 'batch_size': 16, 'split_ratio': 0.8, 'epochs': 25, 'num_workers': 2, 'hybridize': True, 'verbose': False, 'final_fit': False, 'seed': 223, 'data_shape': 416, 'start_epoch': 0, 'transfer': 'coco', 'lr_mode': 'step', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '160,180', 'warmup_lr': 0.0, 'warmup_epochs': 2, 'warmup_iters': 1000, 'warmup_factor': 0.3333333333333333, 'momentum': 0.9, 'wd': 0.0005, 'log_interval': 100, 'save_prefix': 'yolo3_mobilenet1.0_custom', 'save_interval': 10, 'val_interval': 1, 'num_samples': -1, 'no_random_shape': False, 'no_wd': False, 'mixup': False, 'no_mixup_epochs': 20, 'label_smooth': False, 'resume': '', 'syncbn': False, 'reuse_pred_weights': True, 'task_id': 1}
# [Epoch 0] Training cost: 56.244, ObjLoss=318.172,BoxCenterLoss=3.053,BoxScaleLoss=2.045,ClassLoss=0.762
# [Epoch 0] Validation: nfpa=0.09090909090909091 mAP=0.09090909090909091
# [Epoch 1] Training cost: 60.421, ObjLoss=10.967,BoxCenterLoss=3.088,BoxScaleLoss=1.431,ClassLoss=0.637
# [Epoch 1] Validation: nfpa=0.32357649547445666 mAP=0.32357649547445666
# [Epoch 2] Training cost: 52.070, ObjLoss=5.592,BoxCenterLoss=2.988,BoxScaleLoss=1.179,ClassLoss=0.537
# [Epoch 2] Validation: nfpa=0.49594945767827253 mAP=0.49594945767827253
# [Epoch 3] Training cost: 54.350, ObjLoss=4.664,BoxCenterLoss=2.908,BoxScaleLoss=1.247,ClassLoss=0.502
# [Epoch 3] Validation: nfpa=0.5410448850174793 mAP=0.5410448850174793
# [Epoch 4] Training cost: 53.398, ObjLoss=4.225,BoxCenterLoss=2.912,BoxScaleLoss=1.323,ClassLoss=0.448
# [Epoch 4] Validation: nfpa=0.6220460546959431 mAP=0.6220460546959431
# [Epoch 5] Training cost: 53.112, ObjLoss=3.810,BoxCenterLoss=2.892,BoxScaleLoss=1.152,ClassLoss=0.380
# [Epoch 5] Validation: nfpa=0.6146401158946381 mAP=0.6146401158946381
# [Epoch 6] Training cost: 54.244, ObjLoss=3.556,BoxCenterLoss=2.889,BoxScaleLoss=0.996,ClassLoss=0.319
# [Epoch 6] Validation: nfpa=0.6798100522236755 mAP=0.6798100522236755
# [Epoch 7] Training cost: 58.277, ObjLoss=3.515,BoxCenterLoss=2.788,BoxScaleLoss=0.967,ClassLoss=0.267
# [Epoch 7] Validation: nfpa=0.6863507657286028 mAP=0.6863507657286028
# [Epoch 8] Training cost: 51.541, ObjLoss=3.209,BoxCenterLoss=2.823,BoxScaleLoss=1.029,ClassLoss=0.293
# [Epoch 8] Validation: nfpa=0.7143873541886123 mAP=0.7143873541886123
# [Epoch 9] Training cost: 50.002, ObjLoss=2.999,BoxCenterLoss=2.731,BoxScaleLoss=1.019,ClassLoss=0.263
# [Epoch 9] Validation: nfpa=0.753146622303144 mAP=0.753146622303144
# [Epoch 10] Training cost: 54.176, ObjLoss=3.018,BoxCenterLoss=2.713,BoxScaleLoss=0.993,ClassLoss=0.225
# [Epoch 10] Validation: nfpa=0.6929758991498103 mAP=0.6929758991498103
# [Epoch 11] Training cost: 50.833, ObjLoss=2.727,BoxCenterLoss=2.908,BoxScaleLoss=1.018,ClassLoss=0.233
# [Epoch 11] Validation: nfpa=0.7504673453621954 mAP=0.7504673453621954
# [Epoch 12] Training cost: 53.546, ObjLoss=2.958,BoxCenterLoss=2.797,BoxScaleLoss=0.908,ClassLoss=0.198
# [Epoch 12] Validation: nfpa=0.7320563947968571 mAP=0.7320563947968571
# [Epoch 13] Training cost: 51.916, ObjLoss=2.669,BoxCenterLoss=2.853,BoxScaleLoss=0.890,ClassLoss=0.215
# [Epoch 13] Validation: nfpa=0.7451599694751483 mAP=0.7451599694751483
# [Epoch 14] Training cost: 51.135, ObjLoss=3.009,BoxCenterLoss=2.792,BoxScaleLoss=0.866,ClassLoss=0.164
# [Epoch 14] Validation: nfpa=0.8143092193471339 mAP=0.8143092193471339
# [Epoch 15] Training cost: 51.714, ObjLoss=2.575,BoxCenterLoss=2.663,BoxScaleLoss=0.780,ClassLoss=0.149
# [Epoch 15] Validation: nfpa=0.835189461079275 mAP=0.835189461079275
# [Epoch 16] Training cost: 48.271, ObjLoss=2.507,BoxCenterLoss=2.715,BoxScaleLoss=0.877,ClassLoss=0.169
# [Epoch 16] Validation: nfpa=0.6754570548206036 mAP=0.6754570548206036
# [Epoch 17] Training cost: 50.224, ObjLoss=2.406,BoxCenterLoss=2.621,BoxScaleLoss=0.807,ClassLoss=0.128
# [Epoch 17] Validation: nfpa=0.8464200030877314 mAP=0.8464200030877314
# [Epoch 18] Training cost: 50.797, ObjLoss=2.347,BoxCenterLoss=2.683,BoxScaleLoss=0.707,ClassLoss=0.119
# [Epoch 18] Validation: nfpa=0.838709339663489 mAP=0.838709339663489
# [Epoch 19] Training cost: 51.010, ObjLoss=2.527,BoxCenterLoss=2.727,BoxScaleLoss=0.744,ClassLoss=0.120
# [Epoch 19] Validation: nfpa=0.8386927245253909 mAP=0.8386927245253909
# [Epoch 20] Training cost: 56.952, ObjLoss=2.395,BoxCenterLoss=2.616,BoxScaleLoss=0.723,ClassLoss=0.112
# [Epoch 20] Validation: nfpa=0.8475771359231818 mAP=0.8475771359231818
# [Epoch 21] Training cost: 49.802, ObjLoss=2.204,BoxCenterLoss=2.640,BoxScaleLoss=0.679,ClassLoss=0.105
# [Epoch 21] Validation: nfpa=0.8637000103776149 mAP=0.8637000103776149
# [Epoch 22] Training cost: 49.396, ObjLoss=2.310,BoxCenterLoss=2.638,BoxScaleLoss=0.709,ClassLoss=0.121
# [Epoch 22] Validation: nfpa=0.8709780847482508 mAP=0.8709780847482508
# [Epoch 23] Training cost: 54.358, ObjLoss=2.286,BoxCenterLoss=2.696,BoxScaleLoss=0.648,ClassLoss=0.088
# [Epoch 23] Validation: nfpa=0.8492813385723895 mAP=0.8492813385723895
# [Epoch 24] Training cost: 53.093, ObjLoss=2.049,BoxCenterLoss=2.652,BoxScaleLoss=0.702,ClassLoss=0.096
# [Epoch 24] Validation: nfpa=0.875675783012059 mAP=0.875675783012059
# {'meta_arch': 'yolo3', 'dataset': <autogluon.task.object_detection.dataset.voc.CustomVOCDetection object at 0x7f7f5d20acf8>, 'net': 'mobilenet1.0', 'lr': 0.0001, 'loss': SoftmaxCrossEntropyLoss(batch_axis=0, w=None), 'num_gpus': 1, 'batch_size': 16, 'split_ratio': 0.8, 'epochs': 25, 'num_workers': 2, 'hybridize': True, 'verbose': False, 'final_fit': True, 'seed': 223, 'data_shape': 416, 'start_epoch': 0, 'transfer': 'coco', 'lr_mode': 'step', 'lr_decay': 0.1, 'lr_decay_period': 0, 'lr_decay_epoch': '160,180', 'warmup_lr': 0.0, 'warmup_epochs': 2, 'warmup_iters': 1000, 'warmup_factor': 0.3333333333333333, 'momentum': 0.9, 'wd': 0.0005, 'log_interval': 100, 'save_prefix': 'yolo3_mobilenet1.0_custom', 'save_interval': 10, 'val_interval': 1, 'num_samples': -1, 'no_random_shape': False, 'no_wd': False, 'mixup': False, 'no_mixup_epochs': 20, 'label_smooth': False, 'resume': '', 'syncbn': False, 'reuse_pred_weights': True, 'task_id': 2}
# [Epoch 0] Training cost: 64.117, ObjLoss=483.643,BoxCenterLoss=2.967,BoxScaleLoss=1.931,ClassLoss=0.766
# [Epoch 1] Training cost: 61.693, ObjLoss=8.710,BoxCenterLoss=2.887,BoxScaleLoss=1.254,ClassLoss=0.608
# [Epoch 2] Training cost: 62.307, ObjLoss=5.004,BoxCenterLoss=3.022,BoxScaleLoss=1.172,ClassLoss=0.535
# [Epoch 3] Training cost: 68.817, ObjLoss=4.030,BoxCenterLoss=2.945,BoxScaleLoss=1.090,ClassLoss=0.460
# [Epoch 4] Training cost: 63.504, ObjLoss=3.850,BoxCenterLoss=2.973,BoxScaleLoss=1.041,ClassLoss=0.390
# [Epoch 5] Training cost: 75.950, ObjLoss=4.190,BoxCenterLoss=2.910,BoxScaleLoss=1.095,ClassLoss=0.347
# [Epoch 6] Training cost: 64.320, ObjLoss=3.439,BoxCenterLoss=2.923,BoxScaleLoss=0.986,ClassLoss=0.292
# [Epoch 7] Training cost: 72.659, ObjLoss=2.947,BoxCenterLoss=2.826,BoxScaleLoss=0.946,ClassLoss=0.240
# [Epoch 8] Training cost: 73.909, ObjLoss=3.120,BoxCenterLoss=2.800,BoxScaleLoss=0.997,ClassLoss=0.230
# [Epoch 9] Training cost: 71.530, ObjLoss=3.157,BoxCenterLoss=2.855,BoxScaleLoss=0.874,ClassLoss=0.195
# [Epoch 10] Training cost: 67.659, ObjLoss=2.562,BoxCenterLoss=2.845,BoxScaleLoss=0.909,ClassLoss=0.193
# [Epoch 11] Training cost: 63.783, ObjLoss=2.733,BoxCenterLoss=2.757,BoxScaleLoss=0.799,ClassLoss=0.168
# [Epoch 12] Training cost: 68.303, ObjLoss=2.664,BoxCenterLoss=2.785,BoxScaleLoss=0.845,ClassLoss=0.175
# [Epoch 13] Training cost: 63.827, ObjLoss=2.414,BoxCenterLoss=2.724,BoxScaleLoss=0.839,ClassLoss=0.155
# [Epoch 14] Training cost: 74.867, ObjLoss=2.717,BoxCenterLoss=2.805,BoxScaleLoss=0.788,ClassLoss=0.130
# [Epoch 15] Training cost: 62.904, ObjLoss=2.217,BoxCenterLoss=2.632,BoxScaleLoss=0.781,ClassLoss=0.135
# [Epoch 16] Training cost: 63.186, ObjLoss=2.282,BoxCenterLoss=2.707,BoxScaleLoss=0.803,ClassLoss=0.138
# [Epoch 17] Training cost: 69.890, ObjLoss=2.508,BoxCenterLoss=2.682,BoxScaleLoss=0.698,ClassLoss=0.115
# [Epoch 18] Training cost: 68.600, ObjLoss=2.065,BoxCenterLoss=2.700,BoxScaleLoss=0.676,ClassLoss=0.108
# [Epoch 19] Training cost: 59.742, ObjLoss=1.934,BoxCenterLoss=2.579,BoxScaleLoss=0.652,ClassLoss=0.114
# [Epoch 20] Training cost: 76.375, ObjLoss=2.396,BoxCenterLoss=2.720,BoxScaleLoss=0.651,ClassLoss=0.096
# [Epoch 21] Training cost: 61.474, ObjLoss=2.128,BoxCenterLoss=2.597,BoxScaleLoss=0.808,ClassLoss=0.108
# [Epoch 22] Training cost: 67.289, ObjLoss=2.299,BoxCenterLoss=2.682,BoxScaleLoss=0.751,ClassLoss=0.102
# [Epoch 23] Training cost: 59.924, ObjLoss=1.915,BoxCenterLoss=2.673,BoxScaleLoss=0.669,ClassLoss=0.087
# [Epoch 24] Training cost: 68.028, ObjLoss=1.815,BoxCenterLoss=2.502,BoxScaleLoss=0.791,ClassLoss=0.074
# Saving Training Curve in checkpoint/plot_training_curves.png
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> finish model fitting
# The best config: {'lr.choice': 1, 'net.choice': 0}

# %%
dataset_test = task.Dataset(data_root, index_file_name='test', classes=('nfpa',))

test_map = detector.evaluate(dataset_test)
print("mAP on test dataset: {}".format(test_map[1][1]))
# Out:
# >>> create dataset(VOC format)
# mAP on test dataset: 0.8111888111888113

# %%
image = 'pos-230.jpg'
image_path = os.path.join(data_root, 'JPEGImages', image)

ind, prob, loc = detector.predict(image_path)

# %%
image = 'pos-23.jpg'
image_path = os.path.join(data_root, 'JPEGImages', image)

ind, prob, loc = detector.predict(image_path)

# %%
image = 'pos-201.jpg'
image_path = os.path.join(data_root, 'JPEGImages', image)

ind, prob, loc = detector.predict(image_path)

# %%
savefile = 'model.pkl'
detector.save(savefile)

from autogluon import Detector
new_detector = Detector.load(savefile)

# %%
# !ls
# Out:
# checkpoint	   model.pkl	yolo3_mobilenet1.0_custom_train.log
# dask-worker-space  sample_data
